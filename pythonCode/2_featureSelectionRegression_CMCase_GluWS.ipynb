# %% [markdown]
# # Feature Selection for Regression Data

# %% [markdown]
# Source: https://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

# %% [raw]
# FACTORS
# 1. Data: TPM
# 2: Enzyme: CMCase
# 3. Input Medium: WS
# 4. Method: Linear Regression

# %% [markdown]
# # Step0: Define Input Output

# %%
##Define parameters
dataType = "normReadCount"
enzyme = "Act_CMCase"
medium = "GlucoseWS"
method = "LinearRegression"

numPreSelectGene = 50

##Define output
pathOut = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\2_pythonNoteBook_normReadCount\\"
outFileListGene50 = pathOut+"50_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"
outFileTopGene = pathOut+"top_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"

# %% [markdown]
# # Step1: Data Loading and preparing

# %%
##Import Required Modules
import plotly.express as px
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
##Loading Data (CSV format)
#url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/1_input_normReadCount_profile.csv'
url = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\1_input_expression\\1_input_normReadCount_lot2_cutGene.csv"
dataLot2=pd.read_csv(url)
dataLot2.head()
#dataLot2 =  dataLot2[dataLot2['medium']==medium]
# Out:
#    strain   Lot   medium  sampleName  time strain_medium strain_time  \
# 0  BCC199  Lot2  Glucose  BCC199_G3F  Day3      BCC199_G   BCC199_H3
# 1  BCC199  Lot2  Glucose  BCC199_G3H  Day3      BCC199_G   BCC199_H3
# 2  BCC199  Lot2  Glucose  BCC199_G6M  Day6      BCC199_G   BCC199_H6
# 3  BCC199  Lot2  Glucose  BCC199_G6N  Day6      BCC199_G   BCC199_H6
# 4  BCC199  Lot2       WS  BCC199_S3K  Day3      BCC199_S   BCC199_H3
#
#     strain_lot   medium_time  Act_CMCase  ...  acu08286_1  acu08287_1  \
# 0  BCC199_Lot2  Glucose_Day3       0.437  ...   13.734621  340.855199
# 1  BCC199_Lot2  Glucose_Day3       0.353  ...   16.417992  199.378158
# 2  BCC199_Lot2  Glucose_Day6       0.364  ...    8.365875  198.957898
# 3  BCC199_Lot2  Glucose_Day6       0.299  ...   16.510022  227.446326
# 4  BCC199_Lot2       WS_Day3       8.229  ...   12.350391  238.326348
#
#     acu08288_1   acu08289_1   acu08290_1   acu08291_1  acu08292_1  \
# 0  2543.944640  1802.948878  5382.173306  1292.768122  359.161217
# 1   306.276233   172.653639   507.737989   199.378158  119.204602
# 2   238.549477   130.823552   460.446470   103.201519   78.341690
# 3   431.144619   331.880476   950.213366   265.704381  113.706162
# 4    37.114879     3.063707     2.031854     1.000000  116.567613
#
#     acu08293_1  acu08294_1  acu08295_1
# 0  8595.277379  161.774591  103.672882
# 1  7291.654272   57.532636   13.334393
# 2  6635.812150  160.287053  149.238240
# 3  6684.785616  250.194358  173.678248
# 4  3087.274383   59.815660   55.688246
#
# [5 rows x 8632 columns]

# %%
##Loading functional mapping file
url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/function.xlsx'
function=pd.read_excel(url)
#function.head()

# %%
##Loading functional mapping file
b = open("C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\1_data_exploration\\function.txt",'r').readlines()
del b[0]##delete header

funMap = {}
for i in b:
    iList = i.replace("\n","").split("\t")
    key = iList[1]
    value = iList[11]+"|"+iList[18]
    funMap[key] = value

# %%
dataLot2
# Out:
#       strain   Lot   medium    sampleName  time strain_medium  strain_time  \
# 0     BCC199  Lot2  Glucose    BCC199_G3F  Day3      BCC199_G    BCC199_H3
# 1     BCC199  Lot2  Glucose    BCC199_G3H  Day3      BCC199_G    BCC199_H3
# 2     BCC199  Lot2  Glucose    BCC199_G6M  Day6      BCC199_G    BCC199_H6


# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
featureData = dataLot2.iloc[0:24,17:8632]##split feature value
featureList = list(featureData.columns)
X=dataLot2.iloc[0:24,17:8632].to_numpy()
Y=dataLot2[enzyme].to_numpy()

# %% [markdown]
# # Step2: Feature Selection

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

##Source: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html

# configure to select all features
fs = SelectKBest(score_func=f_regression, k='all')
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)
# Out:
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:299: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:304: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
import matplotlib.pyplot as plt
# what are scores for the features
importantFeature = {}
dataPlotFeature = []
dataPlotScore = []
score = {}

for i in range(len(fs.scores_)):
    if fs.scores_[i] > 10:
        key = featureList[i]
        value = []
        value.append(fs.scores_[i])##Score
        value.append(funMap[featureList[i]])##Function
        importantFeature[key] = value
        dataPlotFeature.append(featureList[i])
        dataPlotScore.append(fs.scores_[i])
        
        ##Adding data into score variable
        score[fs.scores_[i]] = [featureList[i],funMap[featureList[i]]]
# plot the scores
#plt.bar([i for i in range(len(fs.scores_))], fs.scores_)

plt.bar(dataPlotFeature,dataPlotScore)

plt.show()

# %%
##ดึงค่าและเรียงลำดับ feature ที่สำคัญจากน้อยไปมาก
scoreSort = list(score.keys())
scoreSort.sort()
scoreSort.reverse()

##Save selected feature
saveFile = open(outFileListGene50,"w")
header = ["InputType","Enzyme","Medium","Method","GeneId","Score","Function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

for i in scoreSort[0:numPreSelectGene]:
    dataRecord = dataType+"\t"+enzyme.replace("Act_","")+"\t"+medium+"\t"+method+"\t"+score[i][0]+"\t"+str(i)+"\t"+score[i][1]+"\n"
    saveFile.write(dataRecord)
    print (dataRecord)
saveFile.close()
# Out:
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu05636_1	203.89622369533728	Uncharacterized protein|noData
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu04199_1	199.48654921531298	DNA helicase (EC 3.6.4.12)|IPR031327;IPR008049;IPR041024;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu05795_1	140.76851263128108	DNA polymerase (EC 2.7.7.7)|IPR006172;IPR017964;IPR006133;IPR006134;IPR043502;IPR024647;IPR042087;IPR023211;IPR038256;IPR012337;IPR036397;IPR015088;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu00277_2	98.30269642556779	"Endo-1,4-beta-xylanase (EC 3.2.1.8)"|IPR013320;IPR013319;IPR018208;IPR033123;IPR001137;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu01301_1	83.18783740684364	Uncharacterized protein|IPR011545;IPR014001;IPR001650;IPR027417;IPR014014;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu00387_1	81.28018154710247	Lytic polysaccharide monooxygenase (Fragment)|noData
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu00356_2	77.41728793365496	Alpha-galactosidase (EC 3.2.1.22) (Fragment)|IPR013785;IPR004352;IPR017853;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu07040_1	77.01051063576799	Extracellular GDSL-like lipase/acylhydrolase|IPR013830;IPR036514;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu00308_1	73.38297910396203	60S ribosomal export protein NMD3|IPR039768;IPR007064;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu01499_1	72.38697299266234	Uncharacterized protein|IPR013859;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu05367_1	71.77427147866409	MARVEL domain-containing protein|IPR008253;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu05755_1	68.73328888624073	DNA replication licensing factor MCM7 (EC 3.6.4.12)|IPR003593;IPR031327;IPR008050;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu08106_1	66.40085589529794	Aldehyde dehydrogenase PutA|IPR016161;IPR016163;IPR016162;IPR015590;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu04299_1	63.40919468134251	Aspartic protease pep1|IPR001461;IPR001969;IPR034163;IPR033121;IPR021109;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu00040_1	60.54787046175309	TPR domain protein|IPR011990;IPR013105;IPR019734;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu08280_1	59.3870801167816	Amb_all domain-containing protein|IPR002022;IPR012334;IPR011050;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu00443_1	58.75512265148212	Uncharacterized protein|IPR023346;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu05658_1	57.374262703821586	DNA helicase (EC 3.6.4.12)|IPR031327;IPR008047;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# normReadCount	CMCase	GlucoseWS	LinearRegression	acu
import sklearn
from sklearn.linear_model import LinearRegression
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 0.22.1

# %%
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
##คำนวณ Percent Accumulated Adjusted R-square
featureScore = {}
for i in importantFeature.keys():
    featureScore[importantFeature[i][0]] = i

# %%
featureScoreList = list(featureScore.keys())
featureScoreList.sort()
featureScoreList.reverse()
#featureScoreList ## ==> sorted feature score
topFeatureList = []
for i in featureScoreList:
    topFeatureList.append(featureScore[i])

# %%
## ทดสอบหาจำนวน feature ที่เหมาะสมในการสร้างโมเดล
saveFile = open(outFileTopGene,"w")
header = ["No.feature","featureId(geneId)","Adj. R square","No.increasingValue","function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

numBestFeature = 0
cutoff = 0.99
accum_adj_Rsquare = []
selectedFeature = []

print ("\t".join(header))

for feature in topFeatureList:
    selectedFeature.append(feature)
    A=dataLot2[selectedFeature]
    B=dataLot2[enzyme].to_numpy()
    model.fit(A, B)
    score = model.score(A, B)
    accum_adj_Rsquare.append(score)
    
    geneFunction = funMap[feature]##Function
    if len(selectedFeature) > 1:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[-2])+"\t"+geneFunction+"\n"
        print (dataRecord)
    else:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[0])+"\t"+geneFunction+"\n"
        print (dataRecord)
        
    saveFile.write(dataRecord)
    
    if score >= cutoff:
        numBestFeature = len(selectedFeature)
        break
        
saveFile.close()
accum_adj_Rsquare = np.array(accum_adj_Rsquare)
# Out:
# No.feature	featureId(geneId)	Adj. R square	No.increasingValue	function
# 1	acu05636_1	0.8964671613285992	0.0	Uncharacterized protein|noData
#
# 2	acu04199_1	0.9584532103649595	0.06198604903636029	DNA helicase (EC 3.6.4.12)|IPR031327;IPR008049;IPR041024;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# 3	acu05795_1	0.9585147789645538	6.156859959438599e-05	DNA polymerase (EC 2.7.7.7)|IPR006172;IPR017964;IPR006133;IPR006134;IPR043502;IPR024647;IPR042087;IPR023211;IPR038256;IPR012337;IPR036397;IPR015088;
#
# 4	acu00277_2	0.9656819912462109	0.007167212281657065	"Endo-1,4-beta-xylanase (EC 3.2.1.8)"|IPR013320;IPR013319;IPR018208;IPR033123;IPR001137;
#
# 5	acu01301_1	0.9660347958046603	0.0003528045584494377	Uncharacterized protein|IPR011545;IPR014001;IPR001650;IPR027417;IPR014014;
#
# 6	acu00387_1	0.9715128327174631	0.005478036912802797	Lytic polysaccharide monooxygenase (Fragment)|noData
#
# 7	acu00356_2	0.9723454921496838	0.0008326594322206615	Alpha-galactosidase (EC 3.2.1.22) (Fragment)|IPR013785;IPR004352;IPR017853;
#
# 8	acu07040_1	0.9735406755473943	0.0011951833977105197	Extracellular GDSL-like lipase/acylhydrolase|IPR013830;IPR036514;
#
# 9	acu00308_1	0.9773244726873912	0.0037837971399968806	60S ribosomal export protein NMD3|IPR039768;IPR007064;
#
# 10	acu01499_1	0.9824775930295507	0.005153120342159534	Uncharacterized protein|IPR013859;
#
# 11	acu05367_1	0.9827870695346986	0.0003094765051478987	MARVEL domain-containing protein|IPR008253;
#
# 12	acu05755_1	0.9864345154000871	0.0036474458653884545	DNA replication licensing factor MCM7 (EC 3.6.4.12)|IPR003593;IPR031327;IPR008050;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# 13	acu08106_1	0.9944981414175135	0.008063626017426384	Aldehyde dehydrogenase PutA|IPR016161;IPR016163;IPR016162;IPR015590;

# %% [markdown]
# พักจบก่อนครับ
