# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [raw]
# Sources:
#     https://ichi.pro/th/4-librari-thi-samarth-danein-kar-eda-ni-khod-python-hnung-brrthad-12178707580590
#     https://ichi.pro/th/kar-wikheraah-khxmul-cheing-sarwc-eda-doy-chi-python-155270509677709

# %% [raw]
# Exploratory Data Analysis (EDA) เป็นแนวทางในการวิเคราะห์ข้อมูลและค้นหารูปแบบข้อมูลเชิงลึกด้านภาพ ฯลฯ ที่ชุดข้อมูลมีอยู่ก่อนดำเนินการสร้างแบบจำลอง คนหนึ่งใช้เวลาส่วนใหญ่ในการทำ EDA เพื่อให้เข้าใจข้อมูลได้ดีขึ้นซึ่งสามารถย่อให้เล็กลงได้โดยใช้เครื่องมือสร้างภาพอัตโนมัติเช่นPandas-Profiling, Sweetviz, AutovizหรือD-Tale
#
# EDA เกี่ยวข้องกับขั้นตอนต่างๆมากมายรวมถึงการทดสอบทางสถิติการแสดงข้อมูลโดยใช้พล็อตประเภทต่างๆและอื่น ๆ อีกมากมาย ขั้นตอนบางประการของ EDA มีการกล่าวถึงด้านล่าง:
#
# คุณภาพของข้อมูลตรวจสอบ:สามารถทำได้โดยใช้ฟังก์ชั่นหมีแพนด้าห้องสมุดชอบdescribe(), info(), dtypes()ฯลฯ มันถูกใช้เพื่อพบคุณสมบัติหลายประเภทข้อมูลของค่าที่ซ้ำกัน, ค่าที่หายไป ฯลฯ
#
# การทดสอบทางสถิติ:การทดสอบทางสถิติบางอย่างเช่นความสัมพันธ์ของเพียร์สันความสัมพันธ์ของสเปียร์แมนการทดสอบเคนดอลและอื่น ๆ จะทำเพื่อให้ได้ความสัมพันธ์ระหว่างคุณสมบัติ สามารถใช้งานได้ใน python โดยใช้ไลบรารีสถิติ
#
# การทดสอบเชิงปริมาณ:การทดสอบเชิงปริมาณบางอย่างใช้เพื่อค้นหาการแพร่กระจายของคุณลักษณะเชิงตัวเลขจำนวนคุณลักษณะเชิงหมวดหมู่ สามารถใช้งานได้ใน python โดยใช้ฟังก์ชันของไลบรารีแพนด้า
#
# การแสดงภาพ: การแสดงภาพคุณลักษณะเป็นสิ่งสำคัญมากในการทำความเข้าใจข้อมูล เทคนิคกราฟิกเช่นกราฟแท่งแผนภูมิวงกลมใช้เพื่อทำความเข้าใจเกี่ยวกับคุณลักษณะที่เป็นหมวดหมู่ในขณะที่แผนภูมิกระจายฮิสโทแกรมจะใช้สำหรับคุณลักษณะเชิงตัวเลข
#
# ประโยชน์ของ EDA:
# 1) ช่วยทำความสะอาดขยะจากชุดข้อมูล
# 2) ช่วยให้ผู้ใช้เข้าใจความสัมพันธ์ระหว่างตัวแปรแต่ละตัว
#
# ผู้คนใช้เวลามากขึ้นในการวิเคราะห์ข้อมูลเชิงสำรวจและการสร้างภาพข้อมูลแต่สามารถลดเวลาได้ด้วยเครื่องมือสร้างภาพอัตโนมัติเช่นPandas-Profiling, Sweetviz, Autoviz และ D-tale
#
# กระบวนการทั้งหมดของ EDA เกี่ยวข้องกับขั้นตอนบางอย่างซึ่งรวมถึงการทดสอบทางสถิติแสดงภาพข้อมูลของเราโดยการสร้างพล็อตต่างๆการตรวจสอบคุณภาพข้อมูลการทดสอบเชิงปริมาณเป็นต้น

# %%
#!pip install --upgrade numpy
#!pip install --upgrade scipy
#!pip install --upgrade pandas

# %%
##Installation
##ถ้ายังไม่ได้ลงโปรแกรม ให้ลงตามนี้นะ

# %%
#pandas-profiling
#!pip install pandas-profiling

# %%
#Sweetviz [Done]
#!pip install sweetviz

# %%
##Autoviz [Done]
#!pip install autoviz

# %%
##dtale [Done]
#!pip install dtale

# %% [raw]
# หลังจากที่ได้ลงแพ็คเกจสำหรับการทำ EDA มาแล้ว ขั้นตอนต่อไปเราจะทำการสำรวจข้อมูลของเรา
# ด้วย Sweetviz, autoviz, และ dtale กับข้อมูล TPM

# %%
#เริ่มต้นด้วยการ Load package ที่จำเป็นสำหรับการทำงาน
import pandas as pd
import numpy as np
import plotly.express as px

# %%
#เริ่มมาดูข้อมูลของเรากัน โดยจะเริ่มจากการโหลดข้อมูลก่อนน๊า โดยข้อมูลจะอัพโหลดไว้ที่ Github
#(เนื่องจากข้อมูลมีจำนวนมาก บาง column อาจไม่ถูกแสดงน๊า)
url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/inputData/1_input_normReadCount_lot2_cutGene.csv'
df=pd.read_csv(url)

#สร้าง Data Lots
dataLot2 =  df[df['Lot']=="Lot2"]

df
# Out:
#       strain   Lot   medium    sampleName  time strain_medium  strain_time  \
# 0     BCC199  Lot2  Glucose    BCC199_G3F  Day3      BCC199_G    BCC199_H3
# 1     BCC199  Lot2  Glucose    BCC199_G3H  Day3      BCC199_G    BCC199_H3
# 2     BCC199  Lot2  Glucose    BCC199_G6M  Day6      BCC199_G    BCC199_H6
# 3     BCC199  Lot2  Glucose    BCC199_G6N  Day6      BCC199_G    BCC199_H6
# 4     BCC199  Lot2       WS    BCC199_S3K  Day3      BCC199_S    BCC199_H3
# 5     BCC199  Lot2       WS    BCC199_S3L  Day3      BCC199_S    BCC199_H3
# 6     BCC199  Lot2       WS    BCC199_S6T  Day6      BCC199_S    BCC199_H6
# 7     BCC199  Lot2       WS    BCC199_S6U  Day6      BCC199_S    BCC199_H6
# 8   BCC56535  Lot2  Glucose  BCC56535_G3F  Day3    BCC56535_G  BCC56535_H3
# 9   BCC56535  Lot2  Glucose  BCC56535_G3H  Day3    BCC56535_G  BCC56535_H3
# 10  BCC56535  Lot2  Glucose  BCC56535_G6M  Day6    BCC56535_G  BCC56535_H6
# ...

# %%
#ดูข้อมูลทั้งหมดของตัวแปร
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Columns: 8640 entries, strain to acu08295_1
# dtypes: float64(8630), int64(1), object(9)
# memory usage: 2.2+ MB

# %%
#เริ่มต้นที่ packagge sweetviz ก่อน
import sweetviz as sv

#ทำกับข้อมูลทั้ง 2 Lots (16 columnแรก)
#EDA using Autoviz
sweet_report = sv.analyze(df.iloc[:,0:17],pairwise_analysis='on')
#Saving results to HTML file
sweet_report.show_html('0_EDA_sweetviz_allLots.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report 0_EDA_sweetviz_allLots.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#ทำกับข้อมูลเฉพาะ lot2 (16 columnแรก)
#EDA using Autoviz
sweet_report = sv.analyze(dataLot2.iloc[:,0:17],pairwise_analysis='on')
#Saving results to HTML file
sweet_report.show_html('0_EDA_sweetviz_lot2.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report 0_EDA_sweetviz_lot2.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
##ข้าม Autoviz ไปก่อนเพราะยังหาวิธีดูข้อมูลจาก dataframe ไม่ได้ (โหลดดูได้แต่ไฟล์ทั้งก้อน)
#import pandas as pd
#from autoviz.AutoViz_Class import AutoViz_Class

#EDA using Autoviz
#autoviz = AutoViz_Class().AutoViz(url)

# %% [markdown]
# ===================================================================================================================

# %%
##Package ถัดมาคือ Dtale
#Installing necessary packages
import dtale

#ทำกับข้อมูลทั้ง 2 Lots (16 columnแรก)
dtale.show(df.iloc[:,0:17])
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-VSJ91NQC:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#ทำกับข้อมูล Lot2 (16 columnแรก)
dtale.show(dataLot2.iloc[:,0:17])
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-VSJ91NQC:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Executing shutdown due to inactivity...
# 2021-05-27 14:44:07,535 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2021-05-27 14:44:11,609 - INFO     - Executing shutdown...

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# ##Feature Selection
# จากที่ได้เห็นว่า ค่า enzyme activity นั้นขึ้นอยู่กับอาหารเลี้ยงเชื้อแล้ว
# เราจะมาลองสร้างโมเดลสำหรับทำนายกลุ่ม activity (CMCase) จากค่า TPM ดู
# โดยเราจะ label class ของ enzyme activity จากตัวเลขเป็น nominal class
# ถ้า Enzyme activity > 1 เราจะ label class เป็น high
# ถ้า Enzyme activity < 1 เราจะ label class เป็น low

# %%
CMCaseClass = ["low","low","low","low","high","high","high","high","low","low","low","low","high","high","high","high","low","low","low","low","high","high","high","high"]
dataLot2["CMCaseClassLabel"] = CMCaseClass
# Out:
# C:\Users\wutto\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataLot2
# Out:
#       strain   Lot   medium    sampleName  time strain_medium  strain_time  \
# 0   BCC56535  Lot2  Glucose  BCC56535_G3F  Day3    BCC56535_G  BCC56535_H3
# 1   BCC56535  Lot2  Glucose  BCC56535_G3H  Day3    BCC56535_G  BCC56535_H3
# 2   BCC56535  Lot2  Glucose  BCC56535_G6M  Day6    BCC56535_G  BCC56535_H6
# 3   BCC56535  Lot2  Glucose  BCC56535_G6N  Day6    BCC56535_G  BCC56535_H6
# 4   BCC56535  Lot2       WS  BCC56535_S3K  Day3    BCC56535_S  BCC56535_H3
# 5   BCC56535  Lot2       WS  BCC56535_S3L  Day3    BCC56535_S  BCC56535_H3
# 6   BCC56535  Lot2       WS  BCC56535_S6T  Day6    BCC56535_S  BCC56535_H6
# 7   BCC56535  Lot2       WS  BCC56535_S6U  Day6    BCC56535_S  BCC56535_H6
# 8     BCC199  Lot2  Glucose    BCC199_G3F  Day3      BCC199_G    BCC199_H3
# 9     BCC199  Lot2  Glucose    BCC199_G3H  Day3      BCC199_G    BCC199_H3
# 10    BCC199  Lot2  Glucose    BCC199_G6M  Day6      BCC199_G    BCC199_H6
# ...

# %%
#เริ่มต้นด้วยการ Load package ที่จำเป็นสำหรับการทำงาน
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## ทำการโหลด package sklearn: Classifier

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn import metrics

# %%
dataLot2.columns
# Out:
# Index(['strain', 'Lot', 'medium', 'sampleName', 'time', 'strain_medium',
#        'strain_time', 'strain_lot', 'Act_CMCase', 'Act_Fpase',
#        ...
#        'acu08287_1', 'acu08288_1', 'acu08289_1', 'acu08290_1', 'acu08291_1',
#        'acu08292_1', 'acu08293_1', 'acu08294_1', 'acu08295_1',
#        'CMCaseClassLabel'],
#       dtype='object', length=8635)

# %% [markdown]
# คัดเลือก important features จาก Random forest โดยแบ่งคลาส enzyme activity เป็น สูง และ ต่ำ

# %%
# เริ่มต้นจากการกำหนด Input และ class label เหมือนในขั้นตอนก่อนหน้า โดย
# input จะเป็น ค่า TPM 
# แต่ class label เป็นค่า Enzyme activity (สูง และ ต่ำ ตาม strain HUT2365, BCC199+BCC56535)

# model= DecisionTreeClassifier(random_state=7)
# model= ExtraTreesClassifier(n_estimators=250, random_state=7)
#X=df[['acu00000_1', 'acu00000_13', 'acu00000_14',
#       'acu00000_15', 'acu00000_2', 'acu00000_4', 'acu00000_5', 'acu00000_9']]

model= RandomForestClassifier(n_estimators=250, random_state=9)
X=dataLot2.iloc[0:24,11:8634]
y=dataLot2['CMCaseClassLabel']
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1f25f66568e6> in <module>
#       8 #       'acu00000_15', 'acu00000_2', 'acu00000_4', 'acu00000_5', 'acu00000_9']]
#       9
# ---> 10 model= RandomForestClassifier(n_estimators=250, random_state=9)
#      11 X=dataLot2.iloc[0:24,11:8634]
#      12 y=dataLot2['CMCaseClassLabel']
#
# NameError: name 'RandomForestClassifier' is not defined
# Executing shutdown due to inactivity...
# 2021-05-14 13:24:27,657 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2021-05-14 13:24:39,989 - INFO     - Executing shutdown...

# %%
model.feature_importances_
fs=pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=True)
fs
# Out:
# acu00000_9    0.000
# acu05371_1    0.000
# acu05370_1    0.000
# acu05369_1    0.000
# acu05368_1    0.000
#               ...
# acu03856_1    0.012
# acu03477_1    0.012
# acu04703_1    0.012
# acu06444_1    0.012
# acu07762_1    0.012
# Length: 8623, dtype: float64

# %%
#คัดกรองเฉพาะ Feature ที่มีค่ามากกว่า 0.001
selectedFeature = fs[fs > 0.01]
print(selectedFeature)
# Out:
# acu06201_1    0.012
# acu00316_1    0.012
# acu03856_1    0.012
# acu03477_1    0.012
# acu04703_1    0.012
# acu06444_1    0.012
# acu07762_1    0.012
# dtype: float64

# %%
#Save Feature ที่ผ่านการคัดกรอง
selectedFeature.to_csv('selectedFeature2Classes.csv', index=True)

# %%
#ทดลอง plot graph แสดง feature ที่มี score มากกว่า 0.005 
fs[fs > 0.01].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
fs.nlargest() #.index
# Out:
# acu06201_1    0.012
# acu00316_1    0.012
# acu03856_1    0.012
# acu03477_1    0.012
# acu04703_1    0.012
# dtype: float64

# %%
## เลือกวิเคราะห์ต่อกับข้อมูลที่แบ่งคลาสเป็นสองคลาสเท่านั้น (Enzyme Activity = สูง และ ต่ำ)
## จากขั้นตอนก่อนหน้า จะได้ important feature จำนวน 5 ยีน
## ขั้นตอนต่อมาเราจะใช้ feature (gene) ทั้ง 5 ตัวดังกล่าว ในการสร้าง model 
## และวัดประสิทธิภาพของ model โดยใช้วิธี split test + confusion matrix

fs[fs > 0.01].index
X=dataLot2[fs[fs > 0.01].index]
y=dataLot2['CMCaseClassLabel']
X
# Out:
#     acu06201_1  acu00316_1   acu03856_1   acu03477_1   acu04703_1  \
# 0   496.642059   23.492491    11.039075   649.373169   678.290710
# 1   463.697113   24.145527    14.519002   446.376984  1057.564087
# 2   556.643921   24.959003    19.548243   486.821106   920.143494
# 3   338.670685   23.490578    24.724434   280.179321  1204.791748
# 4   253.608871   31.479876   819.394836    60.034931    23.473862
# 5   264.470215   82.687775   974.567810    37.659908    38.206009
# 6   281.477173   63.234383   838.269958   195.564484    96.457321
# 7   255.116257   37.014194   788.977661    86.044937    59.778824
# 8   460.190643   23.160864    32.205795  1281.290649   819.510864
# 9   375.621429   18.052551    24.691732   958.366821  1729.567993
# 10  359.714508   29.581831    30.501196   792.375000  1034.717773
# 11  374.764740   29.514286    26.582706   826.563232   708.584534
# 12  162.460907   91.082436   985.957703     8.553907     6.636558
# ...

# %%
# use stratify to split train/test ทำลองทำเพิ่ม 5 fold cross validation
test_size=.3
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=test_size, 
                                                    stratify=y,
                                                    random_state=7)

# %% [markdown]
# ## scikit-learn: confusion matrix
# $$
# \begin{bmatrix}
# C_{0,0} & C_{0,1} \\
# C_{1,0} & C_{1,1}
# \end{bmatrix}
# =
# \begin{bmatrix}
# tn&fp \\
# fn&tp
# \end{bmatrix}
# $$
#
# <table>
# <tr>
#     <td></td>
#     <td>predicted false</td>
#     <td>predicted true</td>
# </tr>
# <tr>
#     <td>actual false</td>
#     <td>tn</td>
#     <td>fp</td>
# </tr>
# <tr>
#     <td>actual true</td>
#     <td>fn</td>
#     <td>tp</td>
# </tr>
# <table>

# %%
## ขั้นตอนนี้จะลองค้นหา important features โดยอาศัย Algorithm อื่น
## แล้วทำการคัดเลือก important features จาก split test + confusion matrix
algo=[
    [KNeighborsClassifier(n_neighbors=3), 'KNeighborsClassifier'], 
    [LogisticRegression(solver='lbfgs'), 'LogisticRegression'], 
    [Perceptron(), 'Perceptron'],
    [DecisionTreeClassifier(min_samples_split=3), 'DecisionTreeClassifier'],
    [GradientBoostingClassifier(), 'GradientBoostingClassifier'],
    [RandomForestClassifier(), 'RandomForestClassifier'],
    [BaggingClassifier(), 'BaggingClassifier'],
    [AdaBoostClassifier(), 'AdaBoostClassifier'],
    [GaussianNB(), 'GaussianNB'],
    [SVC(kernel='linear'), 'SVC_linear']
]
model_scores=[]
for a in algo:
    model = a[0]
    model.fit(X_train, y_train)
    score=model.score(X_test, y_test)
    model_scores.append([score, a[1]])
    y_pred=model.predict(X_test)
    print(f'{a[1]:20} score: {score:.04f}')
    print(metrics.confusion_matrix(y_test, y_pred))
    print(metrics.classification_report(y_test, y_pred))
    print('-' * 100)

print(model_scores)
print(f'best score = {max(model_scores)}')
# Out:
# KNeighborsClassifier score: 1.0000
# [[4 0]
#  [0 4]]
#               precision    recall  f1-score   support
#
#         high       1.00      1.00      1.00         4
#          low       1.00      1.00      1.00         4
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
# ----------------------------------------------------------------------------------------------------
# LogisticRegression   score: 1.0000
# [[4 0]
#  [0 4]]
#               precision    recall  f1-score   support
#
#         high       1.00      1.00      1.00         4
#          low       1.00      1.00      1.00         4
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
# ...

# %% [markdown]
# #เอาล่ะ ทีนี้เราจะมาย้อนดูข้อมูลอีกรอบนึงนะ

# %%
topFeature = dataLot2.iloc[:,0:11]
topFeature["CMCaseClassLabel"] = CMCaseClass
topFeature["acu06201_1"] = dataLot2["acu06201_1"]
topFeature["acu00316_1"] = dataLot2["acu00316_1"]
topFeature["acu03856_1"] = dataLot2["acu03856_1"]
topFeature["acu03477_1"] = dataLot2["acu03477_1"]
topFeature["acu04703_1"] = dataLot2["acu04703_1"]
topFeature["acu06444_1"] = dataLot2["acu06444_1"]
topFeature["acu07762_1"] = dataLot2["acu07762_1"]
topFeature
# Out:
#       strain   Lot   medium    sampleName  time strain_medium  strain_time  \
# 0   BCC56535  Lot2  Glucose  BCC56535_G3F  Day3    BCC56535_G  BCC56535_H3
# 1   BCC56535  Lot2  Glucose  BCC56535_G3H  Day3    BCC56535_G  BCC56535_H3
# 2   BCC56535  Lot2  Glucose  BCC56535_G6M  Day6    BCC56535_G  BCC56535_H6
# 3   BCC56535  Lot2  Glucose  BCC56535_G6N  Day6    BCC56535_G  BCC56535_H6
# 4   BCC56535  Lot2       WS  BCC56535_S3K  Day3    BCC56535_S  BCC56535_H3
# 5   BCC56535  Lot2       WS  BCC56535_S3L  Day3    BCC56535_S  BCC56535_H3
# 6   BCC56535  Lot2       WS  BCC56535_S6T  Day6    BCC56535_S  BCC56535_H6
# 7   BCC56535  Lot2       WS  BCC56535_S6U  Day6    BCC56535_S  BCC56535_H6
# 8     BCC199  Lot2  Glucose    BCC199_G3F  Day3      BCC199_G    BCC199_H3
# 9     BCC199  Lot2  Glucose    BCC199_G3H  Day3      BCC199_G    BCC199_H3
# 10    BCC199  Lot2  Glucose    BCC199_G6M  Day6      BCC199_G    BCC199_H6
# ...

# %%
##เอาล่ะ เราจะมาเริ่มทำ EDA บนข้อมูลที่ได้เลือกมานะ

#ทำกับข้อมูลเฉพาะ lot2 (11 columnแรก)
#EDA using Autoviz
sweet_report = sv.analyze(topFeature,pairwise_analysis='on')
#Saving results to HTML file
sweet_report.show_html('0_EDA_sweetviz_topFeature.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report 0_EDA_sweetviz_topFeature.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#ทำกับข้อมูลทั้ง 2 Lots (11 columnแรก)
dtale.show(topFeature)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-VSJ91NQC:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
##Load function mapping file

func = pd.read_excel('function.xlsx')
func
# Out:
#             selectedGeneId    AcuGeneId    AcuGeneId_BCC199  \
# 0        acu00000_1_BCC199   acu00000_1   acu00000_1_BCC199
# 1      acu00000_10_HUT2365  acu00000_10  acu00000_10_BCC199
# 2       acu00000_11_BCC199  acu00000_11  acu00000_11_BCC199
# 3       acu00000_12_BCC199  acu00000_12  acu00000_12_BCC199
# 4      acu00000_13_HUT2365  acu00000_13  acu00000_13_BCC199
# ...                    ...          ...                 ...
# 13158   acu11279_1_HUT2365   acu11279_1                  ND
# 13159   acu11280_1_HUT2365   acu11280_1                  ND
# 13160   acu11281_1_HUT2365   acu11281_1                  ND
# 13161   acu11282_1_HUT2365   acu11282_1                  ND
# 13162   acu11283_1_HUT2365   acu11283_1                  ND
#
#          AcuGeneId_BCC56535    AcuGeneId_HUT2365  \
# 0       acu00000_1_BCC56535   acu00000_1_HUT2365
# 1                        ND  acu00000_10_HUT2365
# 2      acu00000_11_BCC56535                   ND
# ...

# %%
func[func == "acu00000_11"]
# Out:
#       selectedGeneId    AcuGeneId AcuGeneId_BCC199 AcuGeneId_BCC56535  \
# 0                NaN          NaN              NaN                NaN
# 1                NaN          NaN              NaN                NaN
# 2                NaN  acu00000_11              NaN                NaN
# 3                NaN          NaN              NaN                NaN
# 4                NaN          NaN              NaN                NaN
# ...              ...          ...              ...                ...
# 13158            NaN          NaN              NaN                NaN
# 13159            NaN          NaN              NaN                NaN
# 13160            NaN          NaN              NaN                NaN
# 13161            NaN          NaN              NaN                NaN
# 13162            NaN          NaN              NaN                NaN
#
#       AcuGeneId_HUT2365 method_to_identify_unique_function UniProtHitId  \
# ...
