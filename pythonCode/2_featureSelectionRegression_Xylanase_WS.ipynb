# %% [markdown]
# # Feature Selection for Regression Data

# %% [markdown]
# Source: https://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

# %% [raw]
# FACTORS
# 1. Data: TPM
# 2: Enzyme: CMCase
# 3. Input Medium: WS
# 4. Method: Linear Regression

# %% [markdown]
# # Step0: Define Input Output

# %%
##Define parameters
dataType = "normReadCount"
enzyme = "Act_Xylanase"
medium = "WS"
method = "LinearRegression"

numPreSelectGene = 50

##Define output
pathOut = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\2_pythonNoteBook_normReadCount\\"
outFileListGene50 = pathOut+"50_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"
outFileTopGene = pathOut+"top_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"

# %% [markdown]
# # Step1: Data Loading and preparing

# %%
##Import Required Modules
import plotly.express as px
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
##Loading Data (CSV format)
#url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/1_input_normReadCount_profile.csv'
url = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\1_input_expression\\1_input_normReadCount_lot2_cutGene.csv"
dataLot2=pd.read_csv(url)
dataLot2.head()
dataLot2 =  dataLot2[dataLot2['medium']==medium]

# %%
##Loading functional mapping file
url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/function.xlsx'
function=pd.read_excel(url)
#function.head()

# %%
##Loading functional mapping file
b = open("C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\1_data_exploration\\function.txt",'r').readlines()
del b[0]##delete header

funMap = {}
for i in b:
    iList = i.replace("\n","").split("\t")
    key = iList[1]
    value = iList[11]+"|"+iList[18]
    funMap[key] = value

# %%
dataLot2
# Out:
#       strain   Lot medium    sampleName  time strain_medium  strain_time  \
# 4     BCC199  Lot2     WS    BCC199_S3K  Day3      BCC199_S    BCC199_H3
# 5     BCC199  Lot2     WS    BCC199_S3L  Day3      BCC199_S    BCC199_H3
# 6     BCC199  Lot2     WS    BCC199_S6T  Day6      BCC199_S    BCC199_H6
# 7     BCC199  Lot2     WS    BCC199_S6U  Day6      BCC199_S    BCC199_H6
# 12  BCC56535  Lot2     WS  BCC56535_S3K  Day3    BCC56535_S  BCC56535_H3
# 13  BCC56535  Lot2     WS  BCC56535_S3L  Day3    BCC56535_S  BCC56535_H3
# 14  BCC56535  Lot2     WS  BCC56535_S6T  Day6    BCC56535_S  BCC56535_H6
# 15  BCC56535  Lot2     WS  BCC56535_S6U  Day6    BCC56535_S  BCC56535_H6
# 20   HUT2365  Lot2     WS   HUT2365_S3K  Day3     HUT2365_S   HUT2365_H3
# 21   HUT2365  Lot2     WS   HUT2365_S3L  Day3     HUT2365_S   HUT2365_H3
# 22   HUT2365  Lot2     WS   HUT2365_S6T  Day6     HUT2365_S   HUT2365_H6
# 23   HUT2365  Lot2     WS   HUT2365_S6U  Day6     HUT2365_S   HUT2365_H6
#
#        strain_lot medium_time  Act_CMCase  ...  acu08286_1  acu08287_1  \
# 4     BCC199_Lot2     WS_Day3       8.229  ...   12.350391  238.326348
# 5     BCC199_Lot2     WS_Day3       7.114  ...   57.097389  209.495298
# 6     BCC199_Lot2     WS_Day6      14.978  ...   50.341839  132.578236
# 7     BCC199_Lot2     WS_Day6      12.771  ...   32.591339  141.405950
# 12  BCC56535_Lot2     WS_Day3       5.157  ...   30.920496  656.445870
# 13  BCC56535_Lot2     WS_Day3       4.266  ...   46.581752  732.333884
# 14  BCC56535_Lot2     WS_Day6       9.498  ...   47.662694  844.110048
# 15  BCC56535_Lot2     WS_Day6       9.200  ...  183.932393  904.901236
# 20   HUT2365_Lot2     WS_Day3       9.910  ...   22.167330   71.557767
# 21   HUT2365_Lot2     WS_Day3      10.599  ...   72.673780   59.234946
# 22   HUT2365_Lot2     WS_Day6      19.670  ...   28.799461   53.262987
# 23   HUT2365_Lot2     WS_Day6      19.960  ...   26.589931   66.802680
#
#      acu08288_1  acu08289_1   acu08290_1  acu08291_1   acu08292_1  \
# 4     37.114879    3.063707     2.031854    1.000000   116.567613
# 5     55.227476   11.284521     4.739826    1.934956   109.454953
# 6     72.271545   25.122677   120.516898   13.061338    13.061338
# 7     96.944066    9.190347    79.393322   16.210645     3.340099
# 12    52.425853    9.415140    59.905977    8.480124   349.760784
# 13    76.969586   23.284412    52.659319   30.374907   751.579513
# 14   981.977100  196.134904   541.863049   55.086305    23.270831
# 15  2577.705471  930.335686  2014.234571  241.649030    66.542622
# 20    83.905376   15.111553   329.093615   20.403386  1631.766382
# 21    95.071836    3.986407   302.627156   24.891260  2893.335651
# 22   247.859214   24.351547   979.541029   79.950469   303.458136
# 23   307.165248   21.106374   903.958999   78.683720   331.841253
#
#      acu08293_1  acu08294_1  acu08295_1
# 4   3087.274383   59.815660   55.688246
# 5   3144.323724   63.642085  110.389910
# 6   3037.167796   64.596147   20.736735
# 7   3143.753178   43.121785    6.850248
# 12  4770.514101  272.154497    1.935016
# 13  5221.629971  691.816771    2.012928
# 14  1484.661581  175.985104    2.060516
# 15  1781.411525  100.781305    1.978248
# 20  2216.513873   20.403386   28.341135
# 21  1456.873650    5.479611   12.945630
# 22  1306.462691    9.895828   12.119784
# 23  2181.627705   11.053187   24.762079
#
# [12 rows x 8632 columns]

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
featureData = dataLot2.iloc[0:24,17:8632]##split feature value
featureList = list(featureData.columns)
X=dataLot2.iloc[0:24,17:8632].to_numpy()
Y=dataLot2[enzyme].to_numpy()

# %% [markdown]
# # Step2: Feature Selection

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

##Source: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html

# configure to select all features
fs = SelectKBest(score_func=f_regression, k='all')
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)
# Out:
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:299: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:304: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
import matplotlib.pyplot as plt
# what are scores for the features
importantFeature = {}
dataPlotFeature = []
dataPlotScore = []
score = {}

for i in range(len(fs.scores_)):
    if fs.scores_[i] > 10:
        key = featureList[i]
        value = []
        value.append(fs.scores_[i])##Score
        value.append(funMap[featureList[i]])##Function
        importantFeature[key] = value
        dataPlotFeature.append(featureList[i])
        dataPlotScore.append(fs.scores_[i])
        
        ##Adding data into score variable
        score[fs.scores_[i]] = [featureList[i],funMap[featureList[i]]]
# plot the scores
#plt.bar([i for i in range(len(fs.scores_))], fs.scores_)

plt.bar(dataPlotFeature,dataPlotScore)

plt.show()

# %%
##ดึงค่าและเรียงลำดับ feature ที่สำคัญจากน้อยไปมาก
scoreSort = list(score.keys())
scoreSort.sort()
scoreSort.reverse()

##Save selected feature
saveFile = open(outFileListGene50,"w")
header = ["InputType","Enzyme","Medium","Method","GeneId","Score","Function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

for i in scoreSort[0:numPreSelectGene]:
    dataRecord = dataType+"\t"+enzyme.replace("Act_","")+"\t"+medium+"\t"+method+"\t"+score[i][0]+"\t"+str(i)+"\t"+score[i][1]+"\n"
    saveFile.write(dataRecord)
    print (dataRecord)
saveFile.close()
# Out:
# normReadCount	Xylanase	WS	LinearRegression	acu05152_1	286.3390983048193	Rick_17kDa_Anti domain-containing protein|IPR008816;IPR002395;
#
# normReadCount	Xylanase	WS	LinearRegression	acu03941_1	256.38726704021724	Chitinase (EC 3.2.1.14)|IPR011583;IPR029070;IPR001223;IPR001579;IPR017853;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00475_2	247.54160673569046	RTA1-domain-containing protein|IPR007568;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00500_2	235.5310770725948	Uncharacterized protein|IPR029030;
#
# normReadCount	Xylanase	WS	LinearRegression	acu02359_1	233.7966512098181	Putative skeletrophin|IPR002110;IPR020683;IPR036770;IPR031469;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04742_1	213.43677598065324	Uncharacterized protein|IPR011009;
#
# normReadCount	Xylanase	WS	LinearRegression	acu06842_1	180.763214303134	GTP-binding protein EsdC|IPR013783;IPR014756;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00518_1	177.41779755759327	FAD-binding PCMH-type domain-containing protein|IPR016166;IPR036318;IPR016167;IPR016169;IPR006094;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00439_2	165.28136213846642	Zn(2)-C6 fungal-type domain-containing protein|IPR001138;IPR036864;
#
# normReadCount	Xylanase	WS	LinearRegression	acu01864_1	164.95772200722155	Putative dimethylallyl tryptophan synthase|IPR033964;IPR017795;IPR012148;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00128_1	159.64762663354065	O-methyltransferase|IPR029063;IPR002935;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04390_1	159.1330784214241	Putative AMP dependent ligase/synthetase|IPR025110;IPR000873;IPR042099;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04387_1	149.6237813512085	Putative P450 monooxygenase|IPR001128;IPR017972;IPR002403;IPR036396;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04386_1	136.92943311555223	Aconitase iron-sulfur domain-containing protein|IPR015931;IPR001030;IPR015928;IPR018136;IPR036008;IPR000573;IPR033940;
#
# normReadCount	Xylanase	WS	LinearRegression	acu01254_1	135.18628225831674	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu01292_1	130.70488399900833	Structural maintenance of chromosomes protein|IPR027417;IPR003395;IPR024704;IPR041741;IPR010935;IPR036277;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00401_1	130.48104585008332	3-isopropylmalate dehydrogenase (EC 1.1.1.85)|IPR019818;IPR024084;IPR004429;
#
# normReadCount	Xylanase	WS	LinearRegression	acu07183_1	128.36986263109844	P-loop containing nucleoside triphosphate hydrolase protein|IPR003593;IPR003959;IPR027417;
#
# normReadCount	Xylanase	WS	LinearRegression	acu07022_1	125.12507315641759	Cytochrome P450|IPR001128;IPR017972;IPR002403;IPR036396;
#
# normReadCount	Xylanase	WS	LinearRegression	acu01024_1	122.8186120234212	Ribosomal protein L36e|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu01936_1	121.83333128026115	DUF2235 domain-containing protein|IPR029058;IPR018712;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04413_1	115.02604765303296	Beta-lactamase/transpeptidase-like protein|IPR001466;IPR012338;IPR021860;
#
# normReadCount	Xylanase	WS	LinearRegression	acu03794_1	113.75649166099458	BRO1-domain-containing protein|IPR025304;IPR004328;IPR038499;IPR012724;IPR002939;IPR001623;IPR018253;IPR008971;IPR001305;IPR036410;IPR036869;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04238_1	113.69476200597562	Uncharacterized protein|IPR019268;
#
# normReadCount	Xylanase	WS	LinearRegression	acu06499_1	112.49020298758442	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu02546_1	109.66191093537886	ATP citrate synthase (EC 2.3.3.8)|IPR013650;IPR032263;IPR016102;
#
# normReadCount	Xylanase	WS	LinearRegression	acu08024_1	107.93168866319397	Uncharacterized protein|IPR008972;
#
# normReadCount	Xylanase	WS	LinearRegression	acu03312_1	107.366495138405	Nuclear pore protein|IPR007231;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00208_2	104.76516339314256	Uncharacterized protein|IPR025110;IPR020845;IPR000873;IPR042099;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00049_4	103.8610377995939	P-loop containing nucleoside triphosphate hydrolase protein|IPR003959;IPR027417;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04381_1	102.98571767224517	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu06295_1	101.66772962835942	"Alpha-1,3-glucanase"|IPR005197;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00251_2	100.09827722785363	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu07020_1	98.33953034681056	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu06652_1	98.06206080448942	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu06536_1	98.00453713308687	Efflux pump antibiotic resistance protein|IPR027417;IPR040632;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04385_1	97.01685718492811	Aldolase|IPR002034;IPR013785;IPR036230;IPR000891;
#
# normReadCount	Xylanase	WS	LinearRegression	acu01297_1	95.9893640066372	ABC transporter|IPR003593;IPR013525;IPR003439;IPR017871;IPR027417;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00744_1	94.50697683721012	TPR_REGION domain-containing protein|IPR031350;IPR013026;IPR011990;IPR019734;
#
# normReadCount	Xylanase	WS	LinearRegression	acu06749_1	93.4417225162425	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu02641_1	92.4968577006701	Uncharacterized protein|IPR021848;
#
# normReadCount	Xylanase	WS	LinearRegression	acu03398_1	91.52197208639625	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu03926_1	91.16815586318204	RRM domain-containing protein|IPR012677;IPR035979;IPR000504;
#
# normReadCount	Xylanase	WS	LinearRegression	acu06244_1	86.36770556307494	Uncharacterized protein|IPR015267;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04239_1	85.26980872857558	Putative short chain type dehydrogenase|IPR036291;
#
# normReadCount	Xylanase	WS	LinearRegression	acu05619_1	85.01635240518114	FAD-binding domain-containing protein|IPR016166;IPR036318;IPR016167;IPR016169;IPR006094;
#
# normReadCount	Xylanase	WS	LinearRegression	acu00216_1	83.95789988032499	Uncharacterized protein|IPR004294;
#
# normReadCount	Xylanase	WS	LinearRegression	acu07182_1	81.7907108580865	Uncharacterized protein|noData
#
# normReadCount	Xylanase	WS	LinearRegression	acu08016_1	80.14737461613267	Annexin|IPR018502;IPR037104;
#
# normReadCount	Xylanase	WS	LinearRegression	acu04435_1	79.88694854028445	Methyltransf_2 domain-containing protein|IPR016461;IPR001077;IPR029063;IPR036388;IPR036390;

# %% [markdown]
# ################################################################################

# %%
#หลังจากที่ได้ทำการคัดเลือก feature ที่มีความสัมพันธ์กันกับค่า enzyme activity มากที่สุดแล้ว
#ขั้นตอนต่อไปคือการนำ feature เหล่านั้นมาทำการสร้าง Regression Model สำหรับทำนาย
#ค่า Enzyme activity

# %% [markdown]
# # Step3: Optimize Number of Features by Accumulated Adjusted R-square

# %%
##Loading Required library
import sklearn
from sklearn.linear_model import LinearRegression
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 0.22.1

# %%
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
##คำนวณ Percent Accumulated Adjusted R-square
featureScore = {}
for i in importantFeature.keys():
    featureScore[importantFeature[i][0]] = i

# %%
featureScoreList = list(featureScore.keys())
featureScoreList.sort()
featureScoreList.reverse()
#featureScoreList ## ==> sorted feature score
topFeatureList = []
for i in featureScoreList:
    topFeatureList.append(featureScore[i])

# %%
## ทดสอบหาจำนวน feature ที่เหมาะสมในการสร้างโมเดล
saveFile = open(outFileTopGene,"w")
header = ["No.feature","featureId(geneId)","Adj. R square","No.increasingValue","function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

numBestFeature = 0
cutoff = 0.99
accum_adj_Rsquare = []
selectedFeature = []

print ("\t".join(header))

for feature in topFeatureList:
    selectedFeature.append(feature)
    A=dataLot2[selectedFeature]
    B=dataLot2[enzyme].to_numpy()
    model.fit(A, B)
    score = model.score(A, B)
    accum_adj_Rsquare.append(score)
    
    geneFunction = funMap[feature]##Function
    if len(selectedFeature) > 1:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[-2])+"\t"+geneFunction+"\n"
        print (dataRecord)
    else:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[0])+"\t"+geneFunction+"\n"
        print (dataRecord)
        
    saveFile.write(dataRecord)
    
    if score >= cutoff:
        numBestFeature = len(selectedFeature)
        break
        
saveFile.close()
accum_adj_Rsquare = np.array(accum_adj_Rsquare)
# Out:
# No.feature	featureId(geneId)	Adj. R square	No.increasingValue	function
# 1	acu05152_1	0.5138814148906161	0.0	Rick_17kDa_Anti domain-containing protein|IPR008816;IPR002395;
#
# 2	acu03941_1	0.9649303829034431	0.451048968012827	Chitinase (EC 3.2.1.14)|IPR011583;IPR029070;IPR001223;IPR001579;IPR017853;
#
# 3	acu00475_2	0.9674428064317185	0.0025124235282754093	RTA1-domain-containing protein|IPR007568;
#
# 4	acu00500_2	0.9736755324959955	0.006232726064276939	Uncharacterized protein|IPR029030;
#
# 5	acu02359_1	0.973707529587989	3.1997091993529736e-05	Putative skeletrophin|IPR002110;IPR020683;IPR036770;IPR031469;
#
# 6	acu04742_1	0.9737377628926542	3.023330466522811e-05	Uncharacterized protein|IPR011009;
#
# 7	acu06842_1	0.9770440413007262	0.003306278408071961	GTP-binding protein EsdC|IPR013783;IPR014756;
#
# 8	acu00518_1	0.9773869548460122	0.0003429135452860388	FAD-binding PCMH-type domain-containing protein|IPR016166;IPR036318;IPR016167;IPR016169;IPR006094;
#
# 9	acu00439_2	0.9792913335520472	0.0019043787060349926	Zn(2)-C6 fungal-type domain-containing protein|IPR001138;IPR036864;
#
# 10	acu01864_1	0.9814522845083739	0.002160950956326624	Putative dimethylallyl tryptophan synthase|IPR033964;IPR017795;IPR012148;
#
# 11	acu00128_1	1.0	0.01854771549162615	O-methyltransferase|IPR029063;IPR002935;

# %% [markdown]
# พักจบก่อนครับ
