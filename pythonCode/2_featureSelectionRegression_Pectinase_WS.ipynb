# %% [markdown]
# # Feature Selection for Regression Data

# %% [markdown]
# Source: https://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

# %% [raw]
# FACTORS
# 1. Data: TPM
# 2: Enzyme: CMCase
# 3. Input Medium: WS
# 4. Method: Linear Regression

# %% [markdown]
# # Step0: Define Input Output

# %%
##Define parameters
dataType = "normReadCount"
enzyme = "Act_Pectinase"
medium = "WS"
method = "LinearRegression"

numPreSelectGene = 50

##Define output
pathOut = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\2_pythonNoteBook_normReadCount\\"
outFileListGene50 = pathOut+"50_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"
outFileTopGene = pathOut+"top_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"

# %% [markdown]
# # Step1: Data Loading and preparing

# %%
##Import Required Modules
import plotly.express as px
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
##Loading Data (CSV format)
#url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/1_input_normReadCount_profile.csv'
url = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\1_input_expression\\1_input_normReadCount_lot2_cutGene.csv"
dataLot2=pd.read_csv(url)
dataLot2.head()
dataLot2 =  dataLot2[dataLot2['medium']==medium]

# %%
##Loading functional mapping file
url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/function.xlsx'
function=pd.read_excel(url)
#function.head()

# %%
##Loading functional mapping file
b = open("C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\1_data_exploration\\function.txt",'r').readlines()
del b[0]##delete header

funMap = {}
for i in b:
    iList = i.replace("\n","").split("\t")
    key = iList[1]
    value = iList[11]+"|"+iList[18]
    funMap[key] = value

# %%
dataLot2
# Out:
#       strain   Lot medium    sampleName  time strain_medium  strain_time  \
# 4     BCC199  Lot2     WS    BCC199_S3K  Day3      BCC199_S    BCC199_H3
# 5     BCC199  Lot2     WS    BCC199_S3L  Day3      BCC199_S    BCC199_H3
# 6     BCC199  Lot2     WS    BCC199_S6T  Day6      BCC199_S    BCC199_H6
# 7     BCC199  Lot2     WS    BCC199_S6U  Day6      BCC199_S    BCC199_H6
# 12  BCC56535  Lot2     WS  BCC56535_S3K  Day3    BCC56535_S  BCC56535_H3
# 13  BCC56535  Lot2     WS  BCC56535_S3L  Day3    BCC56535_S  BCC56535_H3
# 14  BCC56535  Lot2     WS  BCC56535_S6T  Day6    BCC56535_S  BCC56535_H6
# 15  BCC56535  Lot2     WS  BCC56535_S6U  Day6    BCC56535_S  BCC56535_H6
# 20   HUT2365  Lot2     WS   HUT2365_S3K  Day3     HUT2365_S   HUT2365_H3
# 21   HUT2365  Lot2     WS   HUT2365_S3L  Day3     HUT2365_S   HUT2365_H3
# 22   HUT2365  Lot2     WS   HUT2365_S6T  Day6     HUT2365_S   HUT2365_H6
# 23   HUT2365  Lot2     WS   HUT2365_S6U  Day6     HUT2365_S   HUT2365_H6
#
#        strain_lot medium_time  Act_CMCase  ...  acu08286_1  acu08287_1  \
# 4     BCC199_Lot2     WS_Day3       8.229  ...   12.350391  238.326348
# 5     BCC199_Lot2     WS_Day3       7.114  ...   57.097389  209.495298
# 6     BCC199_Lot2     WS_Day6      14.978  ...   50.341839  132.578236
# 7     BCC199_Lot2     WS_Day6      12.771  ...   32.591339  141.405950
# 12  BCC56535_Lot2     WS_Day3       5.157  ...   30.920496  656.445870
# 13  BCC56535_Lot2     WS_Day3       4.266  ...   46.581752  732.333884
# 14  BCC56535_Lot2     WS_Day6       9.498  ...   47.662694  844.110048
# 15  BCC56535_Lot2     WS_Day6       9.200  ...  183.932393  904.901236
# 20   HUT2365_Lot2     WS_Day3       9.910  ...   22.167330   71.557767
# 21   HUT2365_Lot2     WS_Day3      10.599  ...   72.673780   59.234946
# 22   HUT2365_Lot2     WS_Day6      19.670  ...   28.799461   53.262987
# 23   HUT2365_Lot2     WS_Day6      19.960  ...   26.589931   66.802680
#
#      acu08288_1  acu08289_1   acu08290_1  acu08291_1   acu08292_1  \
# 4     37.114879    3.063707     2.031854    1.000000   116.567613
# 5     55.227476   11.284521     4.739826    1.934956   109.454953
# 6     72.271545   25.122677   120.516898   13.061338    13.061338
# 7     96.944066    9.190347    79.393322   16.210645     3.340099
# 12    52.425853    9.415140    59.905977    8.480124   349.760784
# 13    76.969586   23.284412    52.659319   30.374907   751.579513
# 14   981.977100  196.134904   541.863049   55.086305    23.270831
# 15  2577.705471  930.335686  2014.234571  241.649030    66.542622
# 20    83.905376   15.111553   329.093615   20.403386  1631.766382
# 21    95.071836    3.986407   302.627156   24.891260  2893.335651
# 22   247.859214   24.351547   979.541029   79.950469   303.458136
# 23   307.165248   21.106374   903.958999   78.683720   331.841253
#
#      acu08293_1  acu08294_1  acu08295_1
# 4   3087.274383   59.815660   55.688246
# 5   3144.323724   63.642085  110.389910
# 6   3037.167796   64.596147   20.736735
# 7   3143.753178   43.121785    6.850248
# 12  4770.514101  272.154497    1.935016
# 13  5221.629971  691.816771    2.012928
# 14  1484.661581  175.985104    2.060516
# 15  1781.411525  100.781305    1.978248
# 20  2216.513873   20.403386   28.341135
# 21  1456.873650    5.479611   12.945630
# 22  1306.462691    9.895828   12.119784
# 23  2181.627705   11.053187   24.762079
#
# [12 rows x 8632 columns]

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
featureData = dataLot2.iloc[0:24,17:8632]##split feature value
featureList = list(featureData.columns)
X=dataLot2.iloc[0:24,17:8632].to_numpy()
Y=dataLot2[enzyme].to_numpy()

# %% [markdown]
# # Step2: Feature Selection

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

##Source: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html

# configure to select all features
fs = SelectKBest(score_func=f_regression, k='all')
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)
# Out:
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:299: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:304: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
import matplotlib.pyplot as plt
# what are scores for the features
importantFeature = {}
dataPlotFeature = []
dataPlotScore = []
score = {}

for i in range(len(fs.scores_)):
    if fs.scores_[i] > 10:
        key = featureList[i]
        value = []
        value.append(fs.scores_[i])##Score
        value.append(funMap[featureList[i]])##Function
        importantFeature[key] = value
        dataPlotFeature.append(featureList[i])
        dataPlotScore.append(fs.scores_[i])
        
        ##Adding data into score variable
        score[fs.scores_[i]] = [featureList[i],funMap[featureList[i]]]
# plot the scores
#plt.bar([i for i in range(len(fs.scores_))], fs.scores_)

plt.bar(dataPlotFeature,dataPlotScore)

plt.show()

# %%
##ดึงค่าและเรียงลำดับ feature ที่สำคัญจากน้อยไปมาก
scoreSort = list(score.keys())
scoreSort.sort()
scoreSort.reverse()

##Save selected feature
saveFile = open(outFileListGene50,"w")
header = ["InputType","Enzyme","Medium","Method","GeneId","Score","Function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

for i in scoreSort[0:numPreSelectGene]:
    dataRecord = dataType+"\t"+enzyme.replace("Act_","")+"\t"+medium+"\t"+method+"\t"+score[i][0]+"\t"+str(i)+"\t"+score[i][1]+"\n"
    saveFile.write(dataRecord)
    print (dataRecord)
saveFile.close()
# Out:
# normReadCount	Pectinase	WS	LinearRegression	acu02193_1	228.01688872836195	S-adenosyl-L-methionine-dependent methyltransferase|IPR029063;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06026_1	138.20891651175302	Mitochondrion protein|IPR001509;IPR036291;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06808_1	117.68788683105241	Kinesin-domain-containing protein|IPR025901;IPR027640;IPR019821;IPR001752;IPR036961;IPR027417;
#
# normReadCount	Pectinase	WS	LinearRegression	acu02921_1	102.71184597378927	Histone deacetylase (EC 3.5.1.98)|IPR019154;IPR000286;IPR023801;IPR037138;IPR017321;IPR023696;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06643_1	87.82612346411965	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu01819_1	87.21751891678123	Kinesin family protein|IPR027640;IPR019821;IPR001752;IPR036961;IPR027417;
#
# normReadCount	Pectinase	WS	LinearRegression	acu01295_1	80.37292736606707	SAICAR synthase-like protein|IPR023610;IPR027483;IPR002498;IPR027484;
#
# normReadCount	Pectinase	WS	LinearRegression	acu01752_1	77.5283545278779	Putative cell wall integrity signaling protein Lsp1|IPR027267;IPR028245;
#
# normReadCount	Pectinase	WS	LinearRegression	acu07965_1	68.46061784792785	WD_REPEATS_REGION domain-containing protein|IPR024977;IPR024738;IPR015943;IPR001680;IPR017986;IPR036322;
#
# normReadCount	Pectinase	WS	LinearRegression	acu02426_1	65.31053396098807	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu05533_1	63.51902296181752	Homocysteine synthase CysD|IPR000277;IPR006235;IPR015424;IPR015422;IPR015421;
#
# normReadCount	Pectinase	WS	LinearRegression	acu02131_1	63.026925252546945	AP complex subunit beta|IPR026739;IPR016342;IPR011989;IPR016024;IPR002553;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06375_1	60.94897700247843	"Altered inheritance of mitochondria protein 24, mitochondrial"|IPR002838;IPR036983;IPR016031;
#
# normReadCount	Pectinase	WS	LinearRegression	acu00649_1	59.915082155917965	Beta-glucosidase (EC 3.2.1.21)|IPR026891;IPR008979;IPR019800;IPR002772;IPR036881;IPR001764;IPR036962;IPR017853;IPR013783;IPR037524;IPR011658;
#
# normReadCount	Pectinase	WS	LinearRegression	acu05731_1	57.73119235601437	Mitochondrial import inner membrane translocase subunit TIM21 (Mitochondrial import inner membrane translocase subunit Tim21)|IPR013261;IPR038552;
#
# normReadCount	Pectinase	WS	LinearRegression	acu03289_1	57.45038116671168	Phosphotransferase (EC 2.7.1.-)|IPR043129;IPR001312;IPR022673;IPR022672;
#
# normReadCount	Pectinase	WS	LinearRegression	acu05730_1	56.36193397892764	L-fuconate dehydratase (EC 4.2.1.68)|IPR036849;IPR029017;IPR029065;IPR034610;IPR018110;IPR013342;IPR013341;
#
# normReadCount	Pectinase	WS	LinearRegression	acu07358_1	54.828824069453105	PH domain protein|IPR011993;IPR001849;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06453_1	54.52130935198119	Uncharacterized protein|IPR002524;IPR027469;IPR002395;
#
# normReadCount	Pectinase	WS	LinearRegression	acu03619_1	54.377938439718974	Uncharacterized protein|IPR008979;IPR013857;IPR039131;
#
# normReadCount	Pectinase	WS	LinearRegression	acu04774_1	52.9408890357347	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu04807_1	51.62228040828286	Elongator complex protein 5|IPR019519;
#
# normReadCount	Pectinase	WS	LinearRegression	acu01646_1	50.367273469586166	WD40 repeat-like protein|IPR020472;IPR007287;IPR015943;IPR001680;IPR017986;IPR036322;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06331_1	50.111225533393636	RNA-binding domain-containing protein|IPR012677;IPR035979;IPR000504;
#
# normReadCount	Pectinase	WS	LinearRegression	acu04250_1	49.630520392419484	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu02630_1	49.00676400001127	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu07421_1	47.326341883620785	Uncharacterized protein|IPR002110;IPR020683;IPR036770;IPR030395;IPR017946;IPR004331;
#
# normReadCount	Pectinase	WS	LinearRegression	acu02766_1	46.76804091576789	Uncharacterized protein|IPR010987;IPR036282;IPR004045;IPR004046;IPR036249;
#
# normReadCount	Pectinase	WS	LinearRegression	acu03035_1	45.57401566255675	Kinesin-like protein|IPR027640;IPR001752;IPR036961;IPR027417;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06322_1	44.14262714738487	CDP-diacylglycerol--serine O-phosphatidyltransferase (EC 2.7.8.8) (Phosphatidylserine synthase)|IPR004533;IPR016271;IPR000462;IPR043130;
#
# normReadCount	Pectinase	WS	LinearRegression	acu07111_1	43.29144201871398	Ubiquitin interaction motif protein|IPR009060;
#
# normReadCount	Pectinase	WS	LinearRegression	acu00805_1	42.25215677826857	Zn(2)-C6 fungal-type domain-containing protein|IPR007219;IPR001138;IPR036864;
#
# normReadCount	Pectinase	WS	LinearRegression	acu04446_1	41.67291027630061	Sulfatase domain protein|IPR017850;IPR000917;
#
# normReadCount	Pectinase	WS	LinearRegression	acu04900_1	41.55841180332876	"Histone-lysine N-methyltransferase, H3 lysine-4 specific (EC 2.1.1.354) (SET domain-containing protein 1)"|IPR024657;IPR012677;IPR003616;IPR035979;IPR017111;IPR024636;IPR001214;
#
# normReadCount	Pectinase	WS	LinearRegression	acu04492_1	39.208307234690714	Creatinase/aminopeptidase|IPR036005;IPR000994;IPR036388;IPR036390;
#
# normReadCount	Pectinase	WS	LinearRegression	acu06100_1	38.36967290529664	HMG box protein|IPR009071;IPR036910;
#
# normReadCount	Pectinase	WS	LinearRegression	acu02297_1	37.90464494168187	Uncharacterized protein|IPR008928;
#
# normReadCount	Pectinase	WS	LinearRegression	acu03494_1	37.64842300039969	Histidine acid phosphatase|IPR000560;IPR029033;IPR016274;
#
# normReadCount	Pectinase	WS	LinearRegression	acu04351_1	37.133343269966716	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu03043_1	37.03978241477857	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu02442_1	37.0127388026867	DUF1749-domain-containing protein|IPR029058;IPR013744;
#
# normReadCount	Pectinase	WS	LinearRegression	acu02785_1	36.98271941690352	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu06133_1	36.76260813704306	V-type proton ATPase subunit a|IPR002490;IPR026028;
#
# normReadCount	Pectinase	WS	LinearRegression	acu08163_1	36.71808163190971	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu07216_1	36.053655529642896	Uncharacterized protein|noData
#
# normReadCount	Pectinase	WS	LinearRegression	acu02345_1	35.66346708633086	F-box domain-containing protein|IPR036047;IPR001810;
#
# normReadCount	Pectinase	WS	LinearRegression	acu00007_5	35.53684457253898	Uncharacterized protein|IPR001128;IPR017972;IPR002401;IPR036396;
#
# normReadCount	Pectinase	WS	LinearRegression	acu00462_1	35.14611048848444	N-acetyltransferase domain-containing protein|IPR016181;IPR000182;
#
# normReadCount	Pectinase	WS	LinearRegression	acu02817_1	34.99549304082368	Uncharacterized protein|IPR022033;IPR013665;IPR015943;IPR001680;IPR036322;
#
# normReadCount	Pectinase	WS	LinearRegression	acu07217_1	34.67661611231917	Zn(2)-C6 fungal-type domain-containing protein|IPR007219;IPR001138;IPR036864;

# %% [markdown]
# ################################################################################

# %%
#หลังจากที่ได้ทำการคัดเลือก feature ที่มีความสัมพันธ์กันกับค่า enzyme activity มากที่สุดแล้ว
#ขั้นตอนต่อไปคือการนำ feature เหล่านั้นมาทำการสร้าง Regression Model สำหรับทำนาย
#ค่า Enzyme activity

# %% [markdown]
# # Step3: Optimize Number of Features by Accumulated Adjusted R-square

# %%
##Loading Required library
import sklearn
from sklearn.linear_model import LinearRegression
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 0.22.1

# %%
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
##คำนวณ Percent Accumulated Adjusted R-square
featureScore = {}
for i in importantFeature.keys():
    featureScore[importantFeature[i][0]] = i

# %%
featureScoreList = list(featureScore.keys())
featureScoreList.sort()
featureScoreList.reverse()
#featureScoreList ## ==> sorted feature score
topFeatureList = []
for i in featureScoreList:
    topFeatureList.append(featureScore[i])

# %%
## ทดสอบหาจำนวน feature ที่เหมาะสมในการสร้างโมเดล
saveFile = open(outFileTopGene,"w")
header = ["No.feature","featureId(geneId)","Adj. R square","No.increasingValue","function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

numBestFeature = 0
cutoff = 0.99
accum_adj_Rsquare = []
selectedFeature = []

print ("\t".join(header))

for feature in topFeatureList:
    selectedFeature.append(feature)
    A=dataLot2[selectedFeature]
    B=dataLot2[enzyme].to_numpy()
    model.fit(A, B)
    score = model.score(A, B)
    accum_adj_Rsquare.append(score)
    
    geneFunction = funMap[feature]##Function
    if len(selectedFeature) > 1:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[-2])+"\t"+geneFunction+"\n"
        print (dataRecord)
    else:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[0])+"\t"+geneFunction+"\n"
        print (dataRecord)
        
    saveFile.write(dataRecord)
    
    if score >= cutoff:
        numBestFeature = len(selectedFeature)
        break
        
saveFile.close()
accum_adj_Rsquare = np.array(accum_adj_Rsquare)
# Out:
# No.feature	featureId(geneId)	Adj. R square	No.increasingValue	function
# 1	acu02193_1	0.15756720172908656	0.0	S-adenosyl-L-methionine-dependent methyltransferase|IPR029063;
#
# 2	acu06026_1	0.5430601840431395	0.38549298231405293	Mitochondrion protein|IPR001509;IPR036291;
#
# 3	acu06808_1	0.6156035519199546	0.07254336787681515	Kinesin-domain-containing protein|IPR025901;IPR027640;IPR019821;IPR001752;IPR036961;IPR027417;
#
# 4	acu02921_1	0.9670470860483189	0.35144353412836427	Histone deacetylase (EC 3.5.1.98)|IPR019154;IPR000286;IPR023801;IPR037138;IPR017321;IPR023696;
#
# 5	acu06643_1	0.968227497370254	0.0011804113219351375	Uncharacterized protein|noData
#
# 6	acu01819_1	0.9682502528075435	2.2755437289467828e-05	Kinesin family protein|IPR027640;IPR019821;IPR001752;IPR036961;IPR027417;
#
# 7	acu01295_1	0.983966133933172	0.015715881125628495	SAICAR synthase-like protein|IPR023610;IPR027483;IPR002498;IPR027484;
#
# 8	acu01752_1	0.984641567007385	0.0006754330742130277	Putative cell wall integrity signaling protein Lsp1|IPR027267;IPR028245;
#
# 9	acu07965_1	0.9847060500304271	6.448302304207232e-05	WD_REPEATS_REGION domain-containing protein|IPR024977;IPR024738;IPR015943;IPR001680;IPR017986;IPR036322;
#
# 10	acu02426_1	0.9973165653336039	0.012610515303176806	Uncharacterized protein|noData

# %% [markdown]
# พักจบก่อนครับ
