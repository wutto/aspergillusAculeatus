# %% [markdown]
# # Feature Selection for Regression Data

# %% [markdown]
# Source: https://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

# %% [raw]
# FACTORS
# 1. Data: TPM
# 2: Enzyme: CMCase
# 3. Input Medium: WS
# 4. Method: Linear Regression

# %% [markdown]
# # Step0: Define Input Output

# %%
##Define parameters
dataType = "normReadCount"
enzyme = "Act_Xylanase"
medium = "GlucoseWS"
method = "LinearRegression"

numPreSelectGene = 50

##Define output
pathOut = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\2_pythonNoteBook_normReadCount\\"
outFileListGene50 = pathOut+"50_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"
outFileTopGene = pathOut+"top_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"

# %% [markdown]
# # Step1: Data Loading and preparing

# %%
##Import Required Modules
import plotly.express as px
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
##Loading Data (CSV format)
#url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/1_input_normReadCount_profile.csv'
url = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\1_input_expression\\1_input_normReadCount_lot2_cutGene.csv"
dataLot2=pd.read_csv(url)
dataLot2.head()
#dataLot2 =  dataLot2[dataLot2['medium']==medium]
# Out:
#    strain   Lot   medium  sampleName  time strain_medium strain_time  \
# 0  BCC199  Lot2  Glucose  BCC199_G3F  Day3      BCC199_G   BCC199_H3
# 1  BCC199  Lot2  Glucose  BCC199_G3H  Day3      BCC199_G   BCC199_H3
# 2  BCC199  Lot2  Glucose  BCC199_G6M  Day6      BCC199_G   BCC199_H6
# 3  BCC199  Lot2  Glucose  BCC199_G6N  Day6      BCC199_G   BCC199_H6
# 4  BCC199  Lot2       WS  BCC199_S3K  Day3      BCC199_S   BCC199_H3
#
#     strain_lot   medium_time  Act_CMCase  ...  acu08286_1  acu08287_1  \
# 0  BCC199_Lot2  Glucose_Day3       0.437  ...   13.734621  340.855199
# 1  BCC199_Lot2  Glucose_Day3       0.353  ...   16.417992  199.378158
# 2  BCC199_Lot2  Glucose_Day6       0.364  ...    8.365875  198.957898
# 3  BCC199_Lot2  Glucose_Day6       0.299  ...   16.510022  227.446326
# 4  BCC199_Lot2       WS_Day3       8.229  ...   12.350391  238.326348
#
#     acu08288_1   acu08289_1   acu08290_1   acu08291_1  acu08292_1  \
# 0  2543.944640  1802.948878  5382.173306  1292.768122  359.161217
# 1   306.276233   172.653639   507.737989   199.378158  119.204602
# 2   238.549477   130.823552   460.446470   103.201519   78.341690
# 3   431.144619   331.880476   950.213366   265.704381  113.706162
# 4    37.114879     3.063707     2.031854     1.000000  116.567613
#
#     acu08293_1  acu08294_1  acu08295_1
# 0  8595.277379  161.774591  103.672882
# 1  7291.654272   57.532636   13.334393
# 2  6635.812150  160.287053  149.238240
# 3  6684.785616  250.194358  173.678248
# 4  3087.274383   59.815660   55.688246
#
# [5 rows x 8632 columns]

# %%
##Loading functional mapping file
url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/function.xlsx'
function=pd.read_excel(url)
#function.head()

# %%
##Loading functional mapping file
b = open("C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\1_data_exploration\\function.txt",'r').readlines()
del b[0]##delete header

funMap = {}
for i in b:
    iList = i.replace("\n","").split("\t")
    key = iList[1]
    value = iList[11]+"|"+iList[18]
    funMap[key] = value

# %%
dataLot2
# Out:
#       strain   Lot   medium    sampleName  time strain_medium  strain_time  \
# 0     BCC199  Lot2  Glucose    BCC199_G3F  Day3      BCC199_G    BCC199_H3
# 1     BCC199  Lot2  Glucose    BCC199_G3H  Day3      BCC199_G    BCC199_H3
# 2     BCC199  Lot2  Glucose    BCC199_G6M  Day6      BCC199_G    BCC199_H6
# 3     BCC199  Lot2  Glucose    BCC199_G6N  Day6      BCC199_G    BCC199_H6
# 4     BCC199  Lot2       WS    BCC199_S3K  Day3      BCC199_S    BCC199_H3
# 5     BCC199  Lot2       WS    BCC199_S3L  Day3      BCC199_S    BCC199_H3
# 6     BCC199  Lot2       WS    BCC199_S6T  Day6      BCC199_S    BCC199_H6
# 7     BCC199  Lot2       WS    BCC199_S6U  Day6      BCC199_S    BCC199_H6
# 8   BCC56535  Lot2  Glucose  BCC56535_G3F  Day3    BCC56535_G  BCC56535_H3
# 9   BCC56535  Lot2  Glucose  BCC56535_G3H  Day3    BCC56535_G  BCC56535_H3
# 10  BCC56535  Lot2  Glucose  BCC56535_G6M  Day6    BCC56535_G  BCC56535_H6
# 11  BCC56535  Lot2  Glucose  BCC56535_G6N  Day6    BCC56535_G  BCC56535_H6
# 12  BCC56535  Lot2       WS  BCC56535_S3K  Day3    BCC56535_S  BCC56535_H3
# 13  BCC56535  Lot2       WS  BCC56535_S3L  Day3    BCC56535_S  BCC56535_H3
# 14  BCC56535  Lot2       WS  BCC56535_S6T  Day6    BCC56535_S  BCC56535_H6
# 15  BCC56535  Lot2       WS  BCC56535_S6U  Day6    BCC56535_S  BCC56535_H6
# 16   HUT2365  Lot2  Glucose   HUT2365_G3F  Day3     HUT2365_G   HUT2365_H3
# 17   HUT2365  Lot2  Glucose   HUT2365_G3H  Day3     HUT2365_G   HUT2365_H3
# 18   HUT2365  Lot2  Glucose   HUT2365_G6M  Day6     HUT2365_G   HUT2365_H6
# 19   HUT2365  Lot2  Glucose   HUT2365_G6N  Day6     HUT2365_G   HUT2365_H6
# 20   HUT2365  Lot2       WS   HUT2365_S3K  Day3     HUT2365_S   HUT2365_H3
# 21   HUT2365  Lot2       WS   HUT2365_S3L  Day3     HUT2365_S   HUT2365_H3
# 22   HUT2365  Lot2       WS   HUT2365_S6T  Day6     HUT2365_S   HUT2365_H6
# 23   HUT2365  Lot2       WS   HUT2365_S6U  Day6     HUT2365_S   HUT2365_H6
#
#        strain_lot   medium_time  Act_CMCase  ...  acu08286_1  acu08287_1  \
# 0     BCC199_Lot2  Glucose_Day3       0.437  ...   13.734621  340.855199
# 1     BCC199_Lot2  Glucose_Day3       0.353  ...   16.417992  199.378158
# 22   247.859214    24.351547   979.541029    79.950469   303.458136
# 23   307.165248    21.106374   903.958999    78.683720   331.841253
#
#      acu08293_1  acu08294_1  acu08295_1
# 0   8595.277379  161.774591  103.672882
# 1   7291.654272   57.532636   13.334393
# 2   6635.812150  160.287053  149.238240
# 3   6684.785616  250.194358  173.678248
# 4   3087.274383   59.815660   55.688246
# 5   3144.323724   63.642085  110.389910
# 6   3037.167796   64.596147   20.736735
# 7   3143.753178   43.121785    6.850248
# 8   2263.415204   40.537353    1.000000
# 9   2486.263670   71.194470    2.897148
# 10  2430.022181  104.523814    1.000000
# 11  2896.515767  112.292190    8.675323
# 12  4770.514101  272.154497    1.935016
# 13  5221.629971  691.816771    2.012928
# 14  1484.661581  175.985104    2.060516
# 15  1781.411525  100.781305    1.978248
# 16  1619.682836    6.013989    6.849654
# 17  1247.672108    5.641370    7.497919
# 18  1283.520326    8.215304    5.509565
# 19  1640.650457    8.111737   10.482316
# 20  2216.513873   20.403386   28.341135
# 21  1456.873650    5.479611   12.945630
# 22  1306.462691    9.895828   12.119784
# 23  2181.627705   11.053187   24.762079
#
# [24 rows x 8632 columns]

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
featureData = dataLot2.iloc[0:24,17:8632]##split feature value
featureList = list(featureData.columns)
X=dataLot2.iloc[0:24,17:8632].to_numpy()
Y=dataLot2[enzyme].to_numpy()

# %% [markdown]
# # Step2: Feature Selection

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

##Source: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html

# configure to select all features
fs = SelectKBest(score_func=f_regression, k='all')
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)
# Out:
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:299: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:304: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
import matplotlib.pyplot as plt
# what are scores for the features
importantFeature = {}
dataPlotFeature = []
dataPlotScore = []
score = {}

for i in range(len(fs.scores_)):
    if fs.scores_[i] > 10:
        key = featureList[i]
        value = []
        value.append(fs.scores_[i])##Score
        value.append(funMap[featureList[i]])##Function
        importantFeature[key] = value
        dataPlotFeature.append(featureList[i])
        dataPlotScore.append(fs.scores_[i])
        
        ##Adding data into score variable
        score[fs.scores_[i]] = [featureList[i],funMap[featureList[i]]]
# plot the scores
#plt.bar([i for i in range(len(fs.scores_))], fs.scores_)

plt.bar(dataPlotFeature,dataPlotScore)

plt.show()

# %%
##ดึงค่าและเรียงลำดับ feature ที่สำคัญจากน้อยไปมาก
scoreSort = list(score.keys())
scoreSort.sort()
scoreSort.reverse()

##Save selected feature
saveFile = open(outFileListGene50,"w")
header = ["InputType","Enzyme","Medium","Method","GeneId","Score","Function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

for i in scoreSort[0:numPreSelectGene]:
    dataRecord = dataType+"\t"+enzyme.replace("Act_","")+"\t"+medium+"\t"+method+"\t"+score[i][0]+"\t"+str(i)+"\t"+score[i][1]+"\n"
    saveFile.write(dataRecord)
    print (dataRecord)
saveFile.close()
# Out:
# normReadCount	Xylanase	GlucoseWS	LinearRegression	ac
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu04510_1	31.64477136854272	FAD/NAD(P)-binding domain-containing protein|IPR036188;IPR038732;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu03531_1	31.603663849187942	Abhydrolase_3 domain-containing protein|IPR029058;IPR013094;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu00523_1	31.46399827399537	Cytochrome P450|IPR001128;IPR017972;IPR002401;IPR036396;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu06842_1	31.00553183281441	GTP-binding protein EsdC|IPR013783;IPR014756;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu00475_2	30.965800454706947	RTA1-domain-containing protein|IPR007568;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu07234_1	30.240985677284648	Uncharacterized protein|IPR015915;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu05239_1	30.238008181910562	DNA helicase (EC 3.6.4.12)|IPR031327;IPR008048;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu00381_2	29.976495362868892	Zn(2)-C6 fungal-type domain-containing protein|IPR021858;IPR001138;IPR036864;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu07612_1	29.67670576137223	DNA helicase (EC 3.6.4.12)|IPR011545;IPR002464;IPR004589;IPR014001;IPR001650;IPR010997;IPR002121;IPR027417;IPR032284;IPR018982;IPR036388;IPR036390;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu06295_1	29.56940273741813	"Alpha-1,3-glucanase"|IPR005197;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu01936_1	29.161140656031655	DUF2235 domain-containing protein|IPR029058;IPR018712;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu07050_1	28.376603070774635	Endonuclease III homolog (EC 3.2.2.-) (EC 4.2.99.18) (Bifunctional DNA N-glycosylase/DNA-(apurinic or apyrimidinic site) lyase) (DNA glycosylase/AP lyase)|IPR011257;IPR004036;IPR003265;IPR000445;IPR023170;IPR030841;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu06517_1	28.056638261442906	Clavaminate synthase-like protein|IPR042098;IPR003819;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu01297_1	28.04423989821644	ABC transporter|IPR003593;IPR013525;IPR003439;IPR017871;IPR027417;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu01905_1	27.856884614061318	Peptidyl-prolyl cis-trans isomerase D|IPR029000;IPR020892;IPR002130;IPR013026;IPR011990;IPR019734;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu04387_1	27.67054720509071	Putative P450 monooxygenase|IPR001128;IPR017972;IPR002403;IPR036396;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu05558_1	27.598545684216706	NADPH--cytochrome P450 reductase (EC 1.6.2.4)|IPR003097;IPR017927;IPR001094;IPR008254;IPR001709;IPR029039;IPR039261;IPR023173;IPR001433;IPR023208;IPR017938;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu00115_1	27.593269171157708	NAD(P)-binding protein|IPR001509;IPR036291;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu03289_1	25.75639736071659	Phosphotransferase (EC 2.7.1.-)|IPR043129;IPR001312;IPR022673;IPR022672;
#
# normReadCount	Xylanase	GlucoseWS	LinearRegression	acu01254_1	25.617577656846944	Uncharacterized protein|noData

# %% [markdown]
# ################################################################################

# %%
#หลังจากที่ได้ทำการคัดเลือก feature ที่มีความสัมพันธ์กันกับค่า enzyme activity มากที่สุดแล้ว
#ขั้นตอนต่อไปคือการนำ feature เหล่านั้นมาทำการสร้าง Regression Model สำหรับทำนาย
#ค่า Enzyme activity

# %% [markdown]
# # Step3: Optimize Number of Features by Accumulated Adjusted R-square

# %%
##Loading Required library
import sklearn
from sklearn.linear_model import LinearRegression
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 0.22.1

# %%
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
##คำนวณ Percent Accumulated Adjusted R-square
featureScore = {}
for i in importantFeature.keys():
    featureScore[importantFeature[i][0]] = i

# %%
featureScoreList = list(featureScore.keys())
featureScoreList.sort()
featureScoreList.reverse()
#featureScoreList ## ==> sorted feature score
topFeatureList = []
for i in featureScoreList:
    topFeatureList.append(featureScore[i])

# %%
## ทดสอบหาจำนวน feature ที่เหมาะสมในการสร้างโมเดล
saveFile = open(outFileTopGene,"w")
header = ["No.feature","featureId(geneId)","Adj. R square","No.increasingValue","function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

numBestFeature = 0
cutoff = 0.99
accum_adj_Rsquare = []
selectedFeature = []

print ("\t".join(header))

for feature in topFeatureList:
    selectedFeature.append(feature)
    A=dataLot2[selectedFeature]
    B=dataLot2[enzyme].to_numpy()
    model.fit(A, B)
    score = model.score(A, B)
    accum_adj_Rsquare.append(score)
    
    geneFunction = funMap[feature]##Function
    if len(selectedFeature) > 1:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[-2])+"\t"+geneFunction+"\n"
        print (dataRecord)
    else:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[0])+"\t"+geneFunction+"\n"
        print (dataRecord)
        
    saveFile.write(dataRecord)
    
    if score >= cutoff:
        numBestFeature = len(selectedFeature)
        break
        
saveFile.close()
accum_adj_Rsquare = np.array(accum_adj_Rsquare)
# Out:
# No.feature	featureId(geneId)	Adj. R square	No.increasingValue	function
# 1	acu07021_1	0.9295804261451192	0.0	Cytochrome P450|IPR001128;IPR017972;IPR002403;IPR036396;
#
# 2	acu05036_1	0.9390801081193048	0.009499681974185603	Non-reducing end alpha-L-arabinofuranosidase (EC 3.2.1.55)|IPR005193;IPR023296;
#
# 3	acu03398_1	0.9455990991330455	0.00651899101374076	Uncharacterized protein|noData
#
# 4	acu00378_1	0.9456429455988619	4.3846465816343994e-05	Uncharacterized protein|noData
#
# 5	acu07022_1	0.9629974058986016	0.01735446029973975	Cytochrome P450|IPR001128;IPR017972;IPR002403;IPR036396;
#
# 6	acu07020_1	0.9631398257102916	0.00014241981168994222	Uncharacterized protein|noData
#
# 7	acu02359_1	0.9643844503110939	0.0012446246008023243	Putative skeletrophin|IPR002110;IPR020683;IPR036770;IPR031469;
#
# 8	acu06617_1	0.9703171814011418	0.0059327310900478825	Uncharacterized protein|noData
#
# 9	acu03794_1	0.9799196595394236	0.009602478138281856	BRO1-domain-containing protein|IPR025304;IPR004328;IPR038499;IPR012724;IPR002939;IPR001623;IPR018253;IPR008971;IPR001305;IPR036410;IPR036869;
#
# 10	acu04442_1	0.9802523970573027	0.00033273751787910033	Uncharacterized protein|noData
#
# 11	acu03401_1	0.9880534759788209	0.007801078921518156	Alpha/beta-hydrolase|IPR029058;IPR000639;IPR010497;IPR016292;
#
# 12	acu05678_1	0.9883246226012921	0.0002711466224711856	"Heat shock protein 60, mitochondrial"|IPR001844;IPR002423;IPR027409;IPR027413;IPR027410;
#
# 13	acu00522_1	0.993284142806913	0.00495952020562096	MFS transporter|IPR011701;IPR020846;IPR036259;

# %% [markdown]
# พักจบก่อนครับ
