# %% [markdown]
# # Feature Selection for Regression Data

# %% [markdown]
# Source: https://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

# %% [raw]
# FACTORS
# 1. Data: TPM
# 2: Enzyme: CMCase
# 3. Input Medium: WS
# 4. Method: Linear Regression

# %% [markdown]
# # Step0: Define Input Output

# %%
##Define parameters
dataType = "normReadCount"
enzyme = "Act_CMCase"
medium = "WS"
method = "LinearRegression"

numPreSelectGene = 50

##Define output
pathOut = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\2_pythonNoteBook_normReadCount\\"
outFileListGene50 = pathOut+"50_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"
outFileTopGene = pathOut+"top_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"

# %% [markdown]
# # Step1: Data Loading and preparing

# %%
##Import Required Modules
import plotly.express as px
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
##Loading Data (CSV format)
#url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/1_input_normReadCount_profile.csv'
url = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\1_input_expression\\1_input_normReadCount_lot2_cutGene.csv"
dataLot2=pd.read_csv(url)
dataLot2.head()
dataLot2 =  dataLot2[dataLot2['medium']==medium]

# %%
##Loading functional mapping file
url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/function.xlsx'
function=pd.read_excel(url)
#function.head()

# %%
##Loading functional mapping file
b = open("C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\1_data_exploration\\function.txt",'r').readlines()
del b[0]##delete header

funMap = {}
for i in b:
    iList = i.replace("\n","").split("\t")
    key = iList[1]
    value = iList[11]+"|"+iList[18]
    funMap[key] = value

# %%
dataLot2
# Out:
#       strain   Lot medium    sampleName  time strain_medium  strain_time  \
# 4     BCC199  Lot2     WS    BCC199_S3K  Day3      BCC199_S    BCC199_H3
# 5     BCC199  Lot2     WS    BCC199_S3L  Day3      BCC199_S    BCC199_H3
# 6     BCC199  Lot2     WS    BCC199_S6T  Day6      BCC199_S    BCC199_H6
# 7     BCC199  Lot2     WS    BCC199_S6U  Day6      BCC199_S    BCC199_H6
# 12  BCC56535  Lot2     WS  BCC56535_S3K  Day3    BCC56535_S  BCC56535_H3
# 13  BCC56535  Lot2     WS  BCC56535_S3L  Day3    BCC56535_S  BCC56535_H3
# 14  BCC56535  Lot2     WS  BCC56535_S6T  Day6    BCC56535_S  BCC56535_H6
# 15  BCC56535  Lot2     WS  BCC56535_S6U  Day6    BCC56535_S  BCC56535_H6
# 20   HUT2365  Lot2     WS   HUT2365_S3K  Day3     HUT2365_S   HUT2365_H3
# 21   HUT2365  Lot2     WS   HUT2365_S3L  Day3     HUT2365_S   HUT2365_H3
# 22   HUT2365  Lot2     WS   HUT2365_S6T  Day6     HUT2365_S   HUT2365_H6
# 23   HUT2365  Lot2     WS   HUT2365_S6U  Day6     HUT2365_S   HUT2365_H6
#
#        strain_lot medium_time  Act_CMCase  ...  acu08286_1  acu08287_1  \
# 4     BCC199_Lot2     WS_Day3       8.229  ...   12.350391  238.326348
# 5     BCC199_Lot2     WS_Day3       7.114  ...   57.097389  209.495298
# 6     BCC199_Lot2     WS_Day6      14.978  ...   50.341839  132.578236
# 7     BCC199_Lot2     WS_Day6      12.771  ...   32.591339  141.405950
# 12  BCC56535_Lot2     WS_Day3       5.157  ...   30.920496  656.445870
# 13  BCC56535_Lot2     WS_Day3       4.266  ...   46.581752  732.333884
# 14  BCC56535_Lot2     WS_Day6       9.498  ...   47.662694  844.110048
# 15  BCC56535_Lot2     WS_Day6       9.200  ...  183.932393  904.901236
# 20   HUT2365_Lot2     WS_Day3       9.910  ...   22.167330   71.557767
# 21   HUT2365_Lot2     WS_Day3      10.599  ...   72.673780   59.234946
# 22   HUT2365_Lot2     WS_Day6      19.670  ...   28.799461   53.262987
# 23   HUT2365_Lot2     WS_Day6      19.960  ...   26.589931   66.802680
#
#      acu08288_1  acu08289_1   acu08290_1  acu08291_1   acu08292_1  \
# 4     37.114879    3.063707     2.031854    1.000000   116.567613
# 5     55.227476   11.284521     4.739826    1.934956   109.454953
# 6     72.271545   25.122677   120.516898   13.061338    13.061338
# 7     96.944066    9.190347    79.393322   16.210645     3.340099
# 12    52.425853    9.415140    59.905977    8.480124   349.760784
# 13    76.969586   23.284412    52.659319   30.374907   751.579513
# 14   981.977100  196.134904   541.863049   55.086305    23.270831
# 15  2577.705471  930.335686  2014.234571  241.649030    66.542622
# 20    83.905376   15.111553   329.093615   20.403386  1631.766382
# 21    95.071836    3.986407   302.627156   24.891260  2893.335651
# 22   247.859214   24.351547   979.541029   79.950469   303.458136
# 23   307.165248   21.106374   903.958999   78.683720   331.841253
#
#      acu08293_1  acu08294_1  acu08295_1
# 4   3087.274383   59.815660   55.688246
# 5   3144.323724   63.642085  110.389910
# 6   3037.167796   64.596147   20.736735
# 7   3143.753178   43.121785    6.850248
# 12  4770.514101  272.154497    1.935016
# 13  5221.629971  691.816771    2.012928
# 14  1484.661581  175.985104    2.060516
# 15  1781.411525  100.781305    1.978248
# 20  2216.513873   20.403386   28.341135
# 21  1456.873650    5.479611   12.945630
# 22  1306.462691    9.895828   12.119784
# 23  2181.627705   11.053187   24.762079
#
# [12 rows x 8632 columns]

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
featureData = dataLot2.iloc[0:24,17:8632]##split feature value
featureList = list(featureData.columns)
X=dataLot2.iloc[0:24,17:8632].to_numpy()
Y=dataLot2[enzyme].to_numpy()

# %% [markdown]
# # Step2: Feature Selection

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

##Source: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html

# configure to select all features
fs = SelectKBest(score_func=f_regression, k='all')
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)
# Out:
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:299: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:304: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
import matplotlib.pyplot as plt
# what are scores for the features
importantFeature = {}
dataPlotFeature = []
dataPlotScore = []
score = {}

for i in range(len(fs.scores_)):
    if fs.scores_[i] > 10:
        key = featureList[i]
        value = []
        value.append(fs.scores_[i])##Score
        value.append(funMap[featureList[i]])##Function
        importantFeature[key] = value
        dataPlotFeature.append(featureList[i])
        dataPlotScore.append(fs.scores_[i])
        
        ##Adding data into score variable
        score[fs.scores_[i]] = [featureList[i],funMap[featureList[i]]]
# plot the scores
#plt.bar([i for i in range(len(fs.scores_))], fs.scores_)

plt.bar(dataPlotFeature,dataPlotScore)

plt.show()

# %%
##ดึงค่าและเรียงลำดับ feature ที่สำคัญจากน้อยไปมาก
scoreSort = list(score.keys())
scoreSort.sort()
scoreSort.reverse()

##Save selected feature
saveFile = open(outFileListGene50,"w")
header = ["InputType","Enzyme","Medium","Method","GeneId","Score","Function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

for i in scoreSort[0:numPreSelectGene]:
    dataRecord = dataType+"\t"+enzyme.replace("Act_","")+"\t"+medium+"\t"+method+"\t"+score[i][0]+"\t"+str(i)+"\t"+score[i][1]+"\n"
    saveFile.write(dataRecord)
    print (dataRecord)
saveFile.close()
# Out:
# normReadCount	CMCase	WS	LinearRegression	acu04199_1	105.87913521207584	DNA helicase (EC 3.6.4.12)|IPR031327;IPR008049;IPR041024;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# normReadCount	CMCase	WS	LinearRegression	acu07975_1	99.32073120679769	GMP synthase [glutamine-hydrolyzing] (EC 6.3.5.2) (GMP synthetase) (Glutamine amidotransferase)|IPR029062;IPR017926;IPR001674;IPR004739;IPR022955;IPR025777;IPR022310;IPR014729;
#
# normReadCount	CMCase	WS	LinearRegression	acu02580_1	86.89229217291569	FAD-binding FR-type domain-containing protein|IPR013112;IPR017927;IPR013130;IPR013121;IPR039261;
#
# normReadCount	CMCase	WS	LinearRegression	acu00387_1	81.87362064560973	Lytic polysaccharide monooxygenase (Fragment)|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu03406_1	81.21156809016672	Endoglucanase V (EC 3.2.1.4)|IPR013320;IPR013319;IPR002594;
#
# normReadCount	CMCase	WS	LinearRegression	acu04831_1	72.29637429490398	Uncharacterized protein|IPR010347;IPR027415;IPR003903;
#
# normReadCount	CMCase	WS	LinearRegression	acu06479_1	71.94969949435243	Uncharacterized protein|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu05855_1	68.62248526425046	WD40 repeat-like protein|IPR020472;IPR013934;IPR015943;IPR001680;IPR019775;IPR017986;IPR036322;
#
# normReadCount	CMCase	WS	LinearRegression	acu03869_1	63.784979392346244	tRNA (guanine-N(7)-)-methyltransferase non-catalytic subunit TRM82 (Transfer RNA methyltransferase 82)|IPR028884;IPR001680;IPR017986;IPR036322;
#
# normReadCount	CMCase	WS	LinearRegression	acu00211_1	56.93514974409956	Glycoside hydrolase family 71 protein|IPR005197;
#
# normReadCount	CMCase	WS	LinearRegression	acu00771_1	55.84765421977393	Terpenoid synthase|IPR008949;
#
# normReadCount	CMCase	WS	LinearRegression	acu03810_1	52.13665451873323	"Acetyltransferase, GNAT family"|IPR016181;IPR000182;
#
# normReadCount	CMCase	WS	LinearRegression	acu05423_1	51.660628572461256	Uncharacterized protein|IPR037231;IPR002164;
#
# normReadCount	CMCase	WS	LinearRegression	acu01639_1	50.85713129638002	S-adenosyl-L-methionine-dependent methyltransferase|IPR025799;IPR041698;IPR029063;
#
# normReadCount	CMCase	WS	LinearRegression	acu03044_1	50.50078797789966	FAD/NAD(P)-binding domain-containing protein|IPR036188;
#
# normReadCount	CMCase	WS	LinearRegression	acu00356_2	48.47203395076374	Alpha-galactosidase (EC 3.2.1.22) (Fragment)|IPR013785;IPR004352;IPR017853;
#
# normReadCount	CMCase	WS	LinearRegression	acu02360_1	47.33984838102456	Uncharacterized protein|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu03059_1	46.3911319944789	S-adenosyl-L-methionine-dependent methyltransferase|IPR025799;IPR041698;IPR029063;IPR036236;
#
# normReadCount	CMCase	WS	LinearRegression	acu04047_1	45.26182634547871	Citrulline--aspartate ligase (EC 6.3.4.5)|IPR001518;IPR018223;IPR023434;IPR024074;IPR014729;
#
# normReadCount	CMCase	WS	LinearRegression	acu02254_1	40.908699385363086	Cysteine hydrolase family protein|IPR000868;IPR036380;
#
# normReadCount	CMCase	WS	LinearRegression	acu04509_1	40.2090722202493	Nitrilase|IPR003010;IPR036526;IPR000132;IPR007219;IPR036864;
#
# normReadCount	CMCase	WS	LinearRegression	acu01866_1	40.16290291131436	C2H2-type domain-containing protein|IPR013087;
#
# normReadCount	CMCase	WS	LinearRegression	acu00213_2	39.98830000015822	Cdpnpt in complex with Thiolodiphosphate and (S) Benzodiazependione|IPR033964;IPR017795;IPR012148;
#
# normReadCount	CMCase	WS	LinearRegression	acu00551_1	38.7449486086806	Putative dioxygenase|IPR000627;IPR015889;
#
# normReadCount	CMCase	WS	LinearRegression	acu07067_1	38.18134953183302	Mannosyl phosphorylinositol ceramide synthase SUR1|IPR007577;IPR029044;
#
# normReadCount	CMCase	WS	LinearRegression	acu03801_1	37.79019645590504	HAUS6_N domain-containing protein|IPR028163;
#
# normReadCount	CMCase	WS	LinearRegression	acu02829_1	36.51721117256451	Spermidine synthase|IPR030374;IPR030373;IPR029063;IPR001045;IPR030668;IPR035246;IPR037163;
#
# normReadCount	CMCase	WS	LinearRegression	acu01370_1	35.94994086837218	Uncharacterized protein (Fragment)|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu00712_1	35.891714715672876	Uncharacterized protein|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu07774_1	35.647558749328326	Uncharacterized protein|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu01411_1	35.58461770555968	Cupin_2 domain-containing protein|IPR013096;IPR014710;IPR011051;
#
# normReadCount	CMCase	WS	LinearRegression	acu00382_1	34.475816874813674	Uncharacterized protein|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu06281_1	34.222278233315244	Fatty acyl-CoA reductase (EC 1.2.1.84)|IPR026055;IPR013120;IPR036291;
#
# normReadCount	CMCase	WS	LinearRegression	acu01283_1	32.99264439934535	HEAT repeat protein|IPR016024;IPR019442;
#
# normReadCount	CMCase	WS	LinearRegression	acu05033_1	32.93317992379973	Uncharacterized protein|IPR022085;
#
# normReadCount	CMCase	WS	LinearRegression	acu04437_1	32.67795877515166	Uncharacterized protein|IPR036444;IPR015141;
#
# normReadCount	CMCase	WS	LinearRegression	acu03523_1	31.981446251041262	Cytochrome P450|IPR001128;IPR002401;IPR036396;
#
# normReadCount	CMCase	WS	LinearRegression	acu04092_1	31.30575511564153	Geranylgeranyl pyrophosphate synthetase|IPR008949;IPR000092;IPR033749;
#
# normReadCount	CMCase	WS	LinearRegression	acu05323_1	31.274410084027057	Zn(2)-C6 fungal-type domain-containing protein|IPR021858;IPR001138;
#
# normReadCount	CMCase	WS	LinearRegression	acu00003_1	30.363653106139154	RTA1 like protein|IPR007568;
#
# normReadCount	CMCase	WS	LinearRegression	acu03222_1	30.336450239771963	DNA replication protein|IPR040184;IPR015408;
#
# normReadCount	CMCase	WS	LinearRegression	acu01696_1	30.038562870819263	Ribosome biogenesis protein ERB1 (Eukaryotic ribosome biogenesis protein 1)|IPR028598;IPR012953;IPR015943;IPR001680;IPR019775;IPR017986;IPR036322;
#
# normReadCount	CMCase	WS	LinearRegression	acu08137_1	29.99518330916981	Uncharacterized protein|noData
#
# normReadCount	CMCase	WS	LinearRegression	acu03936_1	29.836779263475563	Transcription initiation factor TFIID subunit|IPR020472;IPR037783;IPR007582;IPR037264;IPR015943;IPR001680;IPR019775;IPR017986;IPR036322;
#
# normReadCount	CMCase	WS	LinearRegression	acu05707_1	29.357518191625317	Mitochondrial genome maintenance protein MGM101|IPR009446;
#
# normReadCount	CMCase	WS	LinearRegression	acu06055_1	29.058514760914314	Uncharacterized protein|IPR036412;IPR023214;IPR027706;IPR010021;
#
# normReadCount	CMCase	WS	LinearRegression	acu02988_1	27.935137940597855	Putative eukaryotic translation initiation factor 2 alpha subunit|IPR012340;IPR022967;IPR003029;IPR024055;IPR024054;IPR011488;
#
# normReadCount	CMCase	WS	LinearRegression	acu04972_1	27.55182850061746	Uncharacterized protein|IPR029190;IPR029188;IPR007019;
#
# normReadCount	CMCase	WS	LinearRegression	acu05058_1	27.19736829821152	ARM repeat-containing protein|IPR016024;IPR012959;IPR033133;IPR040059;IPR001313;
#
# normReadCount	CMCase	WS	LinearRegression	acu04161_1	26.99951178885705	DBR1-domain-containing protein|IPR004843;IPR007708;IPR041816;

# %% [markdown]
# ################################################################################

# %%
#หลังจากที่ได้ทำการคัดเลือก feature ที่มีความสัมพันธ์กันกับค่า enzyme activity มากที่สุดแล้ว
#ขั้นตอนต่อไปคือการนำ feature เหล่านั้นมาทำการสร้าง Regression Model สำหรับทำนาย
#ค่า Enzyme activity

# %% [markdown]
# # Step3: Optimize Number of Features by Accumulated Adjusted R-square

# %%
##Loading Required library
import sklearn
from sklearn.linear_model import LinearRegression
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 0.22.1

# %%
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
##คำนวณ Percent Accumulated Adjusted R-square
featureScore = {}
for i in importantFeature.keys():
    featureScore[importantFeature[i][0]] = i

# %%
featureScoreList = list(featureScore.keys())
featureScoreList.sort()
featureScoreList.reverse()
#featureScoreList ## ==> sorted feature score
topFeatureList = []
for i in featureScoreList:
    topFeatureList.append(featureScore[i])

# %%
## ทดสอบหาจำนวน feature ที่เหมาะสมในการสร้างโมเดล
saveFile = open(outFileTopGene,"w")
header = ["No.feature","featureId(geneId)","Adj. R square","No.increasingValue","function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

numBestFeature = 0
cutoff = 0.99
accum_adj_Rsquare = []
selectedFeature = []

print ("\t".join(header))

for feature in topFeatureList:
    selectedFeature.append(feature)
    A=dataLot2[selectedFeature]
    B=dataLot2[enzyme].to_numpy()
    model.fit(A, B)
    score = model.score(A, B)
    accum_adj_Rsquare.append(score)
    
    geneFunction = funMap[feature]##Function
    if len(selectedFeature) > 1:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[-2])+"\t"+geneFunction+"\n"
        print (dataRecord)
    else:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[0])+"\t"+geneFunction+"\n"
        print (dataRecord)
        
    saveFile.write(dataRecord)
    
    if score >= cutoff:
        numBestFeature = len(selectedFeature)
        break
        
saveFile.close()
accum_adj_Rsquare = np.array(accum_adj_Rsquare)
# Out:
# No.feature	featureId(geneId)	Adj. R square	No.increasingValue	function
# 1	acu04199_1	0.8640687134724419	0.0	DNA helicase (EC 3.6.4.12)|IPR031327;IPR008049;IPR041024;IPR018525;IPR001208;IPR041562;IPR027925;IPR033762;IPR012340;IPR027417;
#
# 2	acu07975_1	0.8652682990828037	0.0011995856103618197	GMP synthase [glutamine-hydrolyzing] (EC 6.3.5.2) (GMP synthetase) (Glutamine amidotransferase)|IPR029062;IPR017926;IPR001674;IPR004739;IPR022955;IPR025777;IPR022310;IPR014729;
#
# 3	acu02580_1	0.8782324924011143	0.012964193318310668	FAD-binding FR-type domain-containing protein|IPR013112;IPR017927;IPR013130;IPR013121;IPR039261;
#
# 4	acu00387_1	0.9706166920198754	0.0923841996187611	Lytic polysaccharide monooxygenase (Fragment)|noData
#
# 5	acu03406_1	0.9834184664425021	0.012801774422626644	Endoglucanase V (EC 3.2.1.4)|IPR013320;IPR013319;IPR002594;
#
# 6	acu04831_1	0.9855779885065358	0.002159522064033692	Uncharacterized protein|IPR010347;IPR027415;IPR003903;
#
# 7	acu06479_1	0.9855904739464378	1.2485439902065743e-05	Uncharacterized protein|noData
#
# 8	acu05855_1	0.9919340835137647	0.0063436095673268245	WD40 repeat-like protein|IPR020472;IPR013934;IPR015943;IPR001680;IPR019775;IPR017986;IPR036322;

# %% [markdown]
# พักจบก่อนครับ
