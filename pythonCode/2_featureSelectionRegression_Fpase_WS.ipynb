# %% [markdown]
# # Feature Selection for Regression Data

# %% [markdown]
# Source: https://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

# %% [raw]
# FACTORS
# 1. Data: TPM
# 2: Enzyme: CMCase
# 3. Input Medium: WS
# 4. Method: Linear Regression

# %% [markdown]
# # Step0: Define Input Output

# %%
##Define parameters
dataType = "normReadCount"
enzyme = "Act_Fpase"
medium = "WS"
method = "LinearRegression"

numPreSelectGene = 50

##Define output
pathOut = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\2_pythonNoteBook_normReadCount\\"
outFileListGene50 = pathOut+"50_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"
outFileTopGene = pathOut+"top_"+dataType+"_"+enzyme.replace("Act_","")+"_"+medium+"_"+method+".txt"

# %% [markdown]
# # Step1: Data Loading and preparing

# %%
##Import Required Modules
import plotly.express as px
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
##Loading Data (CSV format)
#url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/1_input_normReadCount_profile.csv'
url = "C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\2_experiment_feature_important\\1_input_expression\\1_input_normReadCount_lot2_cutGene.csv"
dataLot2=pd.read_csv(url)
dataLot2.head()
dataLot2 =  dataLot2[dataLot2['medium']==medium]

# %%
##Loading functional mapping file
url='https://raw.githubusercontent.com/wutto/aspergillusAculeatus/main/function.xlsx'
function=pd.read_excel(url)
#function.head()

# %%
##Loading functional mapping file
b = open("C:\\Users\\wutto\\Desktop\\ML_aspergillus_aculeatus\\1_data_exploration\\function.txt",'r').readlines()
del b[0]##delete header

funMap = {}
for i in b:
    iList = i.replace("\n","").split("\t")
    key = iList[1]
    value = iList[11]+"|"+iList[18]
    funMap[key] = value

# %%
dataLot2
# Out:
#       strain   Lot medium    sampleName  time strain_medium  strain_time  \
# 4     BCC199  Lot2     WS    BCC199_S3K  Day3      BCC199_S    BCC199_H3
# 5     BCC199  Lot2     WS    BCC199_S3L  Day3      BCC199_S    BCC199_H3
# 6     BCC199  Lot2     WS    BCC199_S6T  Day6      BCC199_S    BCC199_H6
# 7     BCC199  Lot2     WS    BCC199_S6U  Day6      BCC199_S    BCC199_H6
# 12  BCC56535  Lot2     WS  BCC56535_S3K  Day3    BCC56535_S  BCC56535_H3
# 13  BCC56535  Lot2     WS  BCC56535_S3L  Day3    BCC56535_S  BCC56535_H3
# 14  BCC56535  Lot2     WS  BCC56535_S6T  Day6    BCC56535_S  BCC56535_H6
# 15  BCC56535  Lot2     WS  BCC56535_S6U  Day6    BCC56535_S  BCC56535_H6
# 20   HUT2365  Lot2     WS   HUT2365_S3K  Day3     HUT2365_S   HUT2365_H3
# 21   HUT2365  Lot2     WS   HUT2365_S3L  Day3     HUT2365_S   HUT2365_H3
# 22   HUT2365  Lot2     WS   HUT2365_S6T  Day6     HUT2365_S   HUT2365_H6
# 23   HUT2365  Lot2     WS   HUT2365_S6U  Day6     HUT2365_S   HUT2365_H6
#
#        strain_lot medium_time  Act_CMCase  ...  acu08286_1  acu08287_1  \
# 4     BCC199_Lot2     WS_Day3       8.229  ...   12.350391  238.326348
# 5     BCC199_Lot2     WS_Day3       7.114  ...   57.097389  209.495298
# 6     BCC199_Lot2     WS_Day6      14.978  ...   50.341839  132.578236
# 7     BCC199_Lot2     WS_Day6      12.771  ...   32.591339  141.405950
# 12  BCC56535_Lot2     WS_Day3       5.157  ...   30.920496  656.445870
# 13  BCC56535_Lot2     WS_Day3       4.266  ...   46.581752  732.333884
# 14  BCC56535_Lot2     WS_Day6       9.498  ...   47.662694  844.110048
# 15  BCC56535_Lot2     WS_Day6       9.200  ...  183.932393  904.901236
# 20   HUT2365_Lot2     WS_Day3       9.910  ...   22.167330   71.557767
# 21   HUT2365_Lot2     WS_Day3      10.599  ...   72.673780   59.234946
# 22   HUT2365_Lot2     WS_Day6      19.670  ...   28.799461   53.262987
# 23   HUT2365_Lot2     WS_Day6      19.960  ...   26.589931   66.802680
#
#      acu08288_1  acu08289_1   acu08290_1  acu08291_1   acu08292_1  \
# 4     37.114879    3.063707     2.031854    1.000000   116.567613
# 5     55.227476   11.284521     4.739826    1.934956   109.454953
# 6     72.271545   25.122677   120.516898   13.061338    13.061338
# 7     96.944066    9.190347    79.393322   16.210645     3.340099
# 12    52.425853    9.415140    59.905977    8.480124   349.760784
# 13    76.969586   23.284412    52.659319   30.374907   751.579513
# 14   981.977100  196.134904   541.863049   55.086305    23.270831
# 15  2577.705471  930.335686  2014.234571  241.649030    66.542622
# 20    83.905376   15.111553   329.093615   20.403386  1631.766382
# 21    95.071836    3.986407   302.627156   24.891260  2893.335651
# 22   247.859214   24.351547   979.541029   79.950469   303.458136
# 23   307.165248   21.106374   903.958999   78.683720   331.841253
#
#      acu08293_1  acu08294_1  acu08295_1
# 4   3087.274383   59.815660   55.688246
# 5   3144.323724   63.642085  110.389910
# 6   3037.167796   64.596147   20.736735
# 7   3143.753178   43.121785    6.850248
# 12  4770.514101  272.154497    1.935016
# 13  5221.629971  691.816771    2.012928
# 14  1484.661581  175.985104    2.060516
# 15  1781.411525  100.781305    1.978248
# 20  2216.513873   20.403386   28.341135
# 21  1456.873650    5.479611   12.945630
# 22  1306.462691    9.895828   12.119784
# 23  2181.627705   11.053187   24.762079
#
# [12 rows x 8632 columns]

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
featureData = dataLot2.iloc[0:24,17:8632]##split feature value
featureList = list(featureData.columns)
X=dataLot2.iloc[0:24,17:8632].to_numpy()
Y=dataLot2[enzyme].to_numpy()

# %% [markdown]
# # Step2: Feature Selection

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

##Source: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html

# configure to select all features
fs = SelectKBest(score_func=f_regression, k='all')
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)
# Out:
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:299: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# C:\Users\wutto\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:304: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom

# %%
import matplotlib.pyplot as plt
# what are scores for the features
importantFeature = {}
dataPlotFeature = []
dataPlotScore = []
score = {}

for i in range(len(fs.scores_)):
    if fs.scores_[i] > 10:
        key = featureList[i]
        value = []
        value.append(fs.scores_[i])##Score
        
        ##Adding function
        if featureList[i] not in funMap:
            funMap[featureList[i]] = "NoUniProtFunctionFound"##Without Function
            
        value.append(funMap[featureList[i]])##Function
        importantFeature[key] = value
        dataPlotFeature.append(featureList[i])
        dataPlotScore.append(fs.scores_[i])
        
        ##Adding data into score variable
        score[fs.scores_[i]] = [featureList[i],funMap[featureList[i]]]
# plot the scores
#plt.bar([i for i in range(len(fs.scores_))], fs.scores_)

plt.bar(dataPlotFeature,dataPlotScore)

plt.show()

# %%
##ดึงค่าและเรียงลำดับ feature ที่สำคัญจากน้อยไปมาก
scoreSort = list(score.keys())
scoreSort.sort()
scoreSort.reverse()

##Save selected feature
saveFile = open(outFileListGene50,"w")
header = ["InputType","Enzyme","Medium","Method","GeneId","Score","Function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

for i in scoreSort[0:numPreSelectGene]:
    dataRecord = dataType+"\t"+enzyme.replace("Act_","")+"\t"+medium+"\t"+method+"\t"+score[i][0]+"\t"+str(i)+"\t"+score[i][1]+"\n"
    saveFile.write(dataRecord)
    print (dataRecord)
saveFile.close()
# Out:
# normReadCount	Fpase	WS	LinearRegression	acu06335_1	419.00773290419704	Amidohydro-rel domain-containing protein|IPR006680;IPR011059;IPR032466;
#
# normReadCount	Fpase	WS	LinearRegression	acu06761_1	309.96643701141994	Uncharacterized protein|noData
#
# normReadCount	Fpase	WS	LinearRegression	acu05276_1	306.98708221460595	C6 zinc finger domain protein|IPR040331;IPR001138;IPR036864;
#
# normReadCount	Fpase	WS	LinearRegression	acu01087_1	294.61167968975775	Uncharacterized protein|noData
#
# normReadCount	Fpase	WS	LinearRegression	acu00726_1	290.01600738299476	Zn(2)-C6 fungal-type domain-containing protein|IPR007219;IPR001138;IPR036864;
#
# normReadCount	Fpase	WS	LinearRegression	acu00146_1	277.5874502855581	Dimethylaniline monooxygenase|IPR036188;IPR020946;
#
# normReadCount	Fpase	WS	LinearRegression	acu06790_1	268.9470629725112	SRR1 domain-containing protein|IPR012942;
#
# normReadCount	Fpase	WS	LinearRegression	acu00767_1	254.6422787474653	Uncharacterized protein|IPR008775;
#
# normReadCount	Fpase	WS	LinearRegression	acu00896_1	254.4968606149248	FAD-binding domain-containing protein|IPR012951;IPR016166;IPR036318;IPR006094;
#
# normReadCount	Fpase	WS	LinearRegression	acu06611_1	251.9587847879157	Dihydroxyacid dehydratase|IPR042096;IPR000581;IPR020558;IPR037237;
#
# normReadCount	Fpase	WS	LinearRegression	acu07749_1	237.86154159327964	Alpha/beta-hydrolase|IPR029058;IPR000073;
#
# normReadCount	Fpase	WS	LinearRegression	acu00977_1	237.3566517649329	D-aminoacid aminotransferase-like PLP-dependent enzyme|IPR001544;IPR036038;IPR043132;IPR043131;
#
# normReadCount	Fpase	WS	LinearRegression	acu05284_1	233.15770476886934	Uncharacterized protein|IPR011483;IPR013783;
#
# normReadCount	Fpase	WS	LinearRegression	acu02892_1	203.48042741466628	Associated with spindles and kinetochores protein 1 (DASH complex subunit ASK1) (Outer kinetochore protein ASK1)|IPR013964;
#
# normReadCount	Fpase	WS	LinearRegression	acu00707_1	196.90222928894815	S-adenosyl-L-methionine-dependent methyltransferase|IPR016461;IPR001077;IPR029063;IPR036388;IPR036390;
#
# normReadCount	Fpase	WS	LinearRegression	acu00366_2	184.05099682788352	Alkaline ceramidase family protein|IPR008901;
#
# normReadCount	Fpase	WS	LinearRegression	acu00473_1	174.94506030838002	FSH1 domain-containing protein|IPR029058;IPR005645;
#
# normReadCount	Fpase	WS	LinearRegression	acu01252_1	170.86686282310404	NmrA domain-containing protein (Fragment)|IPR036291;IPR008030;
#
# normReadCount	Fpase	WS	LinearRegression	acu00197_1	169.49955346244732	MFS general substrate transporter|IPR011701;IPR020846;IPR036259;
#
# normReadCount	Fpase	WS	LinearRegression	acu00295_2	157.69440994895314	NAD(P)-binding protein|IPR036291;IPR008030;
#
# normReadCount	Fpase	WS	LinearRegression	acu03954_1	157.44553677309028	rRNA processing protein Pwp1|IPR020472;IPR015943;IPR001680;IPR019775;IPR017986;IPR036322;
#
# normReadCount	Fpase	WS	LinearRegression	acu04260_1	153.81691017003908	Fcf1-domain-containing protein|IPR006984;IPR029060;IPR002716;
#
# normReadCount	Fpase	WS	LinearRegression	acu00006_6	151.2268739143667	Putative ATP-binding cassette transporter|IPR003593;IPR011527;IPR036640;IPR003439;IPR027417;
#
# normReadCount	Fpase	WS	LinearRegression	acu03429_1	147.35812475321893	RNA helicase (EC 3.6.4.13)|IPR011545;IPR014001;IPR001650;IPR027417;IPR000629;IPR014014;
#
# normReadCount	Fpase	WS	LinearRegression	acu01244_1	145.55327818551044	Putative transporter|IPR011701;IPR036259;IPR001411;
#
# normReadCount	Fpase	WS	LinearRegression	acu03459_1	140.0651798189644	RmlC-like cupin|IPR006045;IPR014710;IPR011051;
#
# normReadCount	Fpase	WS	LinearRegression	acu00009_2	139.88375370667342	Acetyl-CoA synthetase-like protein|IPR010071;IPR036736;IPR000873;IPR042099;IPR023213;IPR001242;IPR020806;IPR009081;IPR006162;
#
# normReadCount	Fpase	WS	LinearRegression	acu01260_1	134.82124625698987	Uncharacterized protein|noData
#
# normReadCount	Fpase	WS	LinearRegression	acu00729_2	132.30798939728425	Putative SUMO conjugating enzyme|IPR027230;IPR000608;IPR023313;IPR016135;
#
# normReadCount	Fpase	WS	LinearRegression	acu01799_1	131.4763337923855	Zn(2)-C6 fungal-type domain-containing protein|IPR007219;IPR001138;IPR036864;
#
# normReadCount	Fpase	WS	LinearRegression	acu06442_1	126.18663863557427	Zn(2)-C6 fungal-type domain-containing protein|IPR021858;IPR001138;IPR036864;
#
# normReadCount	Fpase	WS	LinearRegression	acu02362_1	125.30360497297464	Uncharacterized protein|IPR032675;
#
# normReadCount	Fpase	WS	LinearRegression	acu04528_1	121.54409316939686	Sec2p domain-containing protein|IPR040351;IPR009449;
#
# normReadCount	Fpase	WS	LinearRegression	acu05437_1	120.27878057595746	WD40 repeat-like protein|IPR020472;IPR027145;IPR007148;IPR015943;IPR001680;IPR019775;IPR017986;IPR036322;
#
# normReadCount	Fpase	WS	LinearRegression	acu07468_1	119.48094596656124	Mitochondrial thiamine pyrophosphate carrier 1|IPR002067;IPR018108;IPR023395;
#
# normReadCount	Fpase	WS	LinearRegression	acu01788_1	117.11088385252613	Inosine-5'-monophosphate dehydrogenase (IMP dehydrogenase) (IMPD) (IMPDH) (EC 1.1.1.205)|IPR013785;IPR000644;IPR005990;IPR015875;IPR001093;
#
# normReadCount	Fpase	WS	LinearRegression	acu03858_1	116.40136740581565	Multiple RNA-binding domain-containing protein 1|IPR034482;IPR012677;IPR035979;IPR000504;
#
# normReadCount	Fpase	WS	LinearRegression	acu05695_1	116.2393313032075	Clavaminate synthase-like protein|IPR026992;IPR027443;IPR005123;
#
# normReadCount	Fpase	WS	LinearRegression	acu07300_1	116.09988950249047	Uncharacterized protein|IPR018606;
#
# normReadCount	Fpase	WS	LinearRegression	acu00654_1	115.16212085190921	Endocytosis protein end4|IPR011417;IPR013809;IPR008942;IPR035964;IPR002558;IPR030224;IPR031468;
#
# normReadCount	Fpase	WS	LinearRegression	acu07120_1	114.09453220165685	Polyubiquitin binding protein|IPR011989;IPR020472;IPR015155;IPR038122;IPR033510;IPR013535;IPR015943;IPR001680;IPR019775;IPR017986;IPR036322;
#
# normReadCount	Fpase	WS	LinearRegression	acu05186_1	112.41358423926008	Elongation factor Tu|IPR041709;IPR004161;IPR033720;IPR031157;IPR027417;IPR005225;IPR000795;IPR009000;IPR009001;IPR004541;IPR004160;
#
# normReadCount	Fpase	WS	LinearRegression	acu05585_1	110.80634438498704	HTH TFE/IIEalpha-type domain-containing protein|IPR039997;IPR017919;IPR002853;IPR024550;
#
# normReadCount	Fpase	WS	LinearRegression	acu00954_1	108.8844259520532	MFS general substrate transporter|IPR011701;IPR036259;
#
# normReadCount	Fpase	WS	LinearRegression	acu00511_2	107.90135278752416	Glycoside hydrolase family 95 protein|IPR008928;IPR012341;IPR016518;IPR027414;IPR013780;
#
# normReadCount	Fpase	WS	LinearRegression	acu00689_1	104.81589635676312	Amino acid transporter|IPR002293;
#
# normReadCount	Fpase	WS	LinearRegression	acu05126_1	104.2723412030844	Uncharacterized protein|IPR019350;
#
# normReadCount	Fpase	WS	LinearRegression	acu05765_1	104.08117769023661	SH3 domain-containing protein (Fragment)|IPR035552;IPR036028;IPR001452;
#
# normReadCount	Fpase	WS	LinearRegression	acu05342_1	103.03792301079136	Uncharacterized protein (Fragment)|noData
#
# normReadCount	Fpase	WS	LinearRegression	acu08207_1	97.04604175535793	Ribosomal protein L1|IPR023674;IPR028364;IPR016095;

# %% [markdown]
# ################################################################################

# %%
#หลังจากที่ได้ทำการคัดเลือก feature ที่มีความสัมพันธ์กันกับค่า enzyme activity มากที่สุดแล้ว
#ขั้นตอนต่อไปคือการนำ feature เหล่านั้นมาทำการสร้าง Regression Model สำหรับทำนาย
#ค่า Enzyme activity

# %% [markdown]
# # Step3: Optimize Number of Features by Accumulated Adjusted R-square

# %%
##Loading Required library
import sklearn
from sklearn.linear_model import LinearRegression
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 0.22.1

# %%
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
##คำนวณ Percent Accumulated Adjusted R-square
featureScore = {}
for i in importantFeature.keys():
    featureScore[importantFeature[i][0]] = i

# %%
featureScoreList = list(featureScore.keys())
featureScoreList.sort()
featureScoreList.reverse()
#featureScoreList ## ==> sorted feature score
topFeatureList = []
for i in featureScoreList:
    topFeatureList.append(featureScore[i])

# %%
## ทดสอบหาจำนวน feature ที่เหมาะสมในการสร้างโมเดล
saveFile = open(outFileTopGene,"w")
header = ["No.feature","featureId(geneId)","Adj. R square","No.increasingValue","function"]
saveFile.write("\t".join(header))
saveFile.write("\n")

numBestFeature = 0
cutoff = 0.99
accum_adj_Rsquare = []
selectedFeature = []

print ("\t".join(header))

for feature in topFeatureList:
    selectedFeature.append(feature)
    A=dataLot2[selectedFeature]
    B=dataLot2[enzyme].to_numpy()
    model.fit(A, B)
    score = model.score(A, B)
    accum_adj_Rsquare.append(score)
    
    geneFunction = funMap[feature]##Function
    if len(selectedFeature) > 1:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[-2])+"\t"+geneFunction+"\n"
        print (dataRecord)
    else:
        dataRecord = str(len(selectedFeature))+"\t"+feature+"\t"+str(score)+"\t"+str(score-accum_adj_Rsquare[0])+"\t"+geneFunction+"\n"
        print (dataRecord)
        
    saveFile.write(dataRecord)
    
    if score >= cutoff:
        numBestFeature = len(selectedFeature)
        break
        
saveFile.close()
accum_adj_Rsquare = np.array(accum_adj_Rsquare)
# Out:
# No.feature	featureId(geneId)	Adj. R square	No.increasingValue	function
# 1	acu06335_1	0.9043558978328483	0.0	Amidohydro-rel domain-containing protein|IPR006680;IPR011059;IPR032466;
#
# 2	acu06761_1	0.982236908645131	0.07788101081228271	Uncharacterized protein|noData
#
# 3	acu05276_1	0.9870113958816826	0.0047744872365516056	C6 zinc finger domain protein|IPR040331;IPR001138;IPR036864;
#
# 4	acu01087_1	0.9917775527028058	0.004766156821123135	Uncharacterized protein|noData

# %% [markdown]
# พักจบก่อนครับ
